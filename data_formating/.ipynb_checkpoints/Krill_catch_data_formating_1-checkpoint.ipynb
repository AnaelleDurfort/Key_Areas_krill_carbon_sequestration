# %% [markdown]
# # Krill catch data formating
#
# ## Info on these data
# We obtained the non-aggregated "C1 data" from the CCAMLR secretariat. These data gather the krill catch survey from 1988 to 2023. Data from 2006 onward are not aggregated, and before most of them have been resubmited at a haul-by-haul level. However, some of them are in an aggregated format : on 1°x0.5° long-lat rectangle and either 10-days or monthly temporal resolution.
#
# Non-aggregated data means that we have the green weight of krill from each haul, together witht the date and time and localisation to the tenth of degree of both the start and the end of the fishing period.
#
# All Members States agreed to deliver their data (i.e. the fishing data of the fishing vessel under their pavillon) for this study. As they are not publicly available, these data are not shared in the repository.
#
# ## Method for formating the data
#
# ### Temporal aggregation
# We aggregate data at the fishing season level : a CCAMLR fishing season goes from 1rst of December to 30th of November of the next year.
# This allows to have a temporal serie of the catches and see how the spatial distribution evolves with time.
#
# *Then we further aggregate the yearly data over three vast period :*
# - 1988 -2000
# - 2001 - 2010
# - 2011 - 2023
#
# These data are used for the spatial overlap analyses.
#
# ### Spatial aggregation
#
# Some data are already in a aggregated format of 1°x0.5° long-lat rectangles.
#
# First we can further aggregate these data on a 2°x2° cells to match the spatial resolution of the sequestration time.
#
# Most of the data are not aggregated, thus we aggregated them on a 1°x0.5° rectangles as the other data, and then to the 2°x2° "harmonized" resolution.

# %%
# import libraries (ok sous base anaconda)
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np
import pandas as pd
import scipy
import math

# %%
# for pltting maps
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
# Out:
# Cannot find header.dxf (GDAL_DATA is not defined)

# %%
# To be change with local directory of the data
import os
os.chdir('C:/Users/anael/Documents/PhD/4_krill_fisheries_Carbon_seq_time/CCAMLR_data_request/data_extract_648_2023-10-12')
C1_648 = pd.read_csv('C1_648.csv')
# Out:
# C:\Users\anael\AppData\Local\Temp\ipykernel_6844\3192461058.py:4: DtypeWarning: Columns (8,16,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   C1_648 = pd.read_csv('C1_648.csv')

# %%
C1_648
# Out:
#          c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 0          344          NaN             NaN              NaN          NaN
# 1          345          NaN             NaN              NaN          NaN
# 2          346          NaN             NaN              NaN          NaN
# 3          347          NaN             NaN              NaN          NaN
# 4          348          NaN             NaN              NaN          NaN
# ...        ...          ...             ...              ...          ...
# 403527  537073          NaN             NaN              NaN       4677.0
# 403528  537076          NaN             NaN              NaN       4680.0
# 403529  537077          NaN             NaN              NaN       4681.0
# 403530  537078          NaN             NaN              NaN       4682.0
# 403531  537079          NaN             NaN              NaN       4683.0
#
#        fishing_purpose_code  season_ccamlr target_species asd_code  \
# 0                         C           1988            KRI      481
# 1                         C           1988            KRI      482
# 2                         C           1988            KRI      482
# 3                         C           1988            KRI      482
# 4                         C           1988            KRI      482
# ...                     ...            ...            ...      ...
# 403527                    C           2023            KRI      483
# 403528                    C           2023            KRI      483
# 403529                    C           2023            KRI      483
# 403530                    C           2023            KRI      483
# 403531                    C           2023            KRI      483
#
#        trawl_technique  ... latitude_haul_start  longitude_haul_start  \
# 0                    T  ...                 NaN                   NaN
# 1                    T  ...                 NaN                   NaN
# 2                    T  ...                 NaN                   NaN
# 3                    T  ...                 NaN                   NaN
# 4                    T  ...                 NaN                   NaN
# ...                ...  ...                 ...                   ...
# 403527               C  ...           -53.84333             -36.07833
# 403528               C  ...           -53.79000             -36.22000
# 403529               C  ...           -53.79000             -36.22000
# 403530               C  ...           -53.77167             -36.14833
# 403531               C  ...           -53.77167             -36.14833
#
#         latitude_fsr  longitude_fsr  latitude longitude notes  \
# 0             -60.75          -55.5 -60.75000 -55.50000   NaN
# 1             -60.25          -46.5 -60.25000 -46.50000   NaN
# 2             -60.75          -46.5 -60.75000 -46.50000   NaN
# 3             -60.75          -47.5 -60.75000 -47.50000   NaN
# 4             -60.25          -46.5 -60.25000 -46.50000   NaN
# ...              ...            ...       ...       ...   ...
# 403527           NaN            NaN -53.87167 -36.02333   NaN
# 403528           NaN            NaN -53.82167 -36.15333   NaN
# 403529           NaN            NaN -53.82167 -36.15333   NaN
# 403530           NaN            NaN -53.79000 -36.22000   NaN
# 403531           NaN            NaN -53.79000 -36.22000   NaN
#
#        krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h
# 0                 55300.000                    NaN                    NaN
# 1                 98100.000                    NaN                    NaN
# 2                300000.000                    NaN                    NaN
# 3                 22800.000                    NaN                    NaN
# 4                304500.000                    NaN                    NaN
# ...                     ...                    ...                    ...
# 403527             8643.049                    2.0                    2.0
# 403528             6630.144                    2.0                    2.0
# 403529             6630.144                    2.0                    2.0
# 403530             7514.163                    2.0                    2.0
# 403531             7514.163                    2.0                    2.0
#
# [403532 rows x 37 columns]

# %%
# separate the data that are aggregated 
# They are 3 levels of aggragation : day, 10gays, months.
# "10-days" and "month" are aggergated in the 1°x0.5° rectangles but "days" are not

aggragation_level = ['10_day', 'month']

agg_data = C1_648.loc[C1_648['catchperiod_code'].isin(aggragation_level)] # we can keep this part of the dataset (the lat - long fsr are already assigned)
agg_data.shape # (2232, 37)
# Out:
# (2232, 37)

# %% [markdown]
# #### "Day" aggregated data
# For the data aggregarted by days, the coordinates lat-long avialable corresponds to the latitude of the end of the fishing haul.
# We aggregate these coordinates over the 1°x0.5° rectangles by rounding the coordinates to the nearest rectable center point.

# %%
# isolate the 'day agregated data'
day_data = C1_648.loc[C1_648['catchperiod_code'] == 'day']
day_data.shape # (4095, 37)
# Out:
# (4095, 37)

# %%
# round the coordinated of the data on a day aggregation to the nearest midpoint of the 1°x0.25° rectangle:
# to do thise we have to round to the nearst 1/4th of degree for latitude and to the nearrest 1/2 degree for longitude

# we take the integer part and then substract 0.5°
def round_longitude(x):
    if x<0 : 
        return(np.trunc(x) - 0.5)
    if x>=0 :
        return(np.trunc(x) + 0.5)

# for latitude we first round to nearest half and then substract 0.25° (we only have negative values of the latitude)
def round_latitude(y):
    return((np.ceil(y*2)/2) - 0.25)

# %%
day_data['longitude_fsr'] = day_data['longitude'].apply(round_longitude)
day_data['latitude_fsr'] = day_data['latitude'].apply(round_latitude)
day_data
# Out:
# C:\Users\anael\AppData\Local\Temp\ipykernel_6844\2974597215.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_data['longitude_fsr'] = day_data['longitude'].apply(round_longitude)
# C:\Users\anael\AppData\Local\Temp\ipykernel_6844\2974597215.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   day_data['latitude_fsr'] = day_data['latitude'].apply(round_latitude)
#          c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 183       1523          NaN             NaN              NaN       1523.0
# 184       1524          NaN             NaN              NaN       1524.0
# 185       1525          NaN             NaN              NaN       1525.0
# 186       1526          NaN             NaN              NaN       1526.0
# 187       1527          NaN             NaN              NaN       1527.0
# ...        ...          ...             ...              ...          ...
# 130110  242177          NaN             NaN              NaN        160.0
# 130111  242178          NaN             NaN              NaN        161.0
# 130112  242179          NaN             NaN              NaN        162.0
# 130113  242180          NaN             NaN              NaN        163.0
# 130114  242181          NaN             NaN              NaN        164.0
#
#        fishing_purpose_code  season_ccamlr target_species asd_code  \
# 183                       C           1989            KRI      481
# 184                       C           1989            KRI      481
# 185                       C           1989            KRI      481
# 186                       C           1989            KRI      481
# 187                       C           1989            KRI      481
# ...                     ...            ...            ...      ...
# 130110                    C           2005            KRI      483
# 130111                    C           2005            KRI      483
# 130112                    C           2005            KRI      483
# 130113                    C           2005            KRI      483
# 130114                    C           2005            KRI      483
#
#        trawl_technique  ... latitude_haul_start  longitude_haul_start  \
# 183                  T  ...                 NaN                   NaN
# 184                  T  ...                 NaN                   NaN
# 185                  T  ...                 NaN                   NaN
# 186                  T  ...                 NaN                   NaN
# 187                  T  ...                 NaN                   NaN
# ...                ...  ...                 ...                   ...
# 130110               T  ...                 NaN                   NaN
# 130111               T  ...                 NaN                   NaN
# 130112               T  ...                 NaN                   NaN
# 130113               T  ...                 NaN                   NaN
# 130114               T  ...                 NaN                   NaN
#
#         latitude_fsr  longitude_fsr   latitude  longitude         notes  \
# 183           -62.25          -61.5 -62.283333 -61.000000           NaN
# 184           -62.25          -61.5 -62.200000 -61.000000           NaN
# 185           -62.25          -60.5 -62.283333 -60.000000           NaN
# 186           -62.25          -60.5 -62.333333 -60.000000           NaN
# 187           -62.25          -61.5 -62.266667 -61.000000           NaN
# ...              ...            ...        ...        ...           ...
# 130110        -53.75          -36.5 -53.800000 -36.183333  Summary data
# 130111        -53.75          -36.5 -53.783333 -36.133333  Summary data
# 130112        -53.75          -36.5 -53.783333 -36.133333  Summary data
# 130113        -53.75          -36.5 -53.816667 -36.166667  Summary data
# 130114        -53.75          -36.5 -53.816667 -36.333333  Summary data
#
#        krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h
# 183                  5000.0                    NaN                    NaN
# 184                  7000.0                    NaN                    NaN
# 185                  4000.0                    NaN                    NaN
# 186                 10000.0                    NaN                    NaN
# 187                 10000.0                    NaN                    NaN
# ...                     ...                    ...                    ...
# 130110              97855.0                    NaN                    NaN
# 130111               9576.0                    NaN                    NaN
# 130112              97974.0                    NaN                    NaN
# 130113              97735.0                    NaN                    NaN
# 130114              86709.0                    NaN                    NaN
#
# [4095 rows x 37 columns]

# %%
# merge the completed 'day data' with the rest of the aggregated data
agg_data = pd.concat([agg_data, day_data])

agg_data.shape # (6327, 37) OK
# Out:
# (6327, 37)

# %% [markdown]
# ## No aggregation data
#
# For these data we have the coordinates of the start and the end of each trawl tow. For each haul (row in the dataset), we have the krill greenweight.
#
# We face different cases in order to aggregate these data on the spatial grid (i.e. the 1°x0.5° long-lat rectangles).
#
# - Some data have missing values for the latitude and longitude of the starting point
# We first check for these cases and put them aside to be treated like the 'day' aggregated data : we round the known coordinates (the end point of the tow) to the nearest cell center point.
#
# - In most of the cases the start and end coordinates belong to the same cells (1°x0.5° rectangle)
# When the start and end coordinates belong to the same cell, the latitude-fsr adnd longitude-fsr are filled the coordinates of the center point of the corresponding cell and the whole krill catch biomass is assigned to this cell.
#
# - In some cases, the trawl tow is straddling on two cells
# When the start and end coordinates do not belong to the same cell, two rows are created with the latitude-fsr and longitude-fsr of the two cells and the extracted biomass is assigned to each one proportionnaly to the length of the tow belonging to each cell (Here we hypothesis than the tows are in straight lines).

# %%
# extract the not aggregated part of the data set
# note that fsr coordinatesare empty for these rows
unagg_data = C1_648.loc[C1_648['catchperiod_code'] == 'haul']
print(unagg_data.shape) # 397205 rows
unagg_data
# Out:
# (397205, 37)
#          c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 4766     26529          NaN             NaN              NaN          1.0
# 4767     26530          NaN             NaN              NaN          2.0
# 4768     26531          NaN             NaN              NaN          4.0
# 4769     26532          NaN             NaN              NaN          5.0
# 4770     26533          NaN             NaN              NaN          6.0
# ...        ...          ...             ...              ...          ...
# 403527  537073          NaN             NaN              NaN       4677.0
# 403528  537076          NaN             NaN              NaN       4680.0
# 403529  537077          NaN             NaN              NaN       4681.0
# 403530  537078          NaN             NaN              NaN       4682.0
# 403531  537079          NaN             NaN              NaN       4683.0
#
#        fishing_purpose_code  season_ccamlr target_species asd_code  \
# 4766                      C           1998            KRI      481
# 4767                      C           1998            KRI      481
# 4768                      C           1998            KRI      481
# 4769                      C           1998            KRI      481
# 4770                      C           1998            KRI      481
# ...                     ...            ...            ...      ...
# 403527                    C           2023            KRI      483
# 403528                    C           2023            KRI      483
# 403529                    C           2023            KRI      483
# 403530                    C           2023            KRI      483
# 403531                    C           2023            KRI      483
#
#        trawl_technique  ... latitude_haul_start  longitude_haul_start  \
# 4766                 T  ...                 NaN                   NaN
# 4767                 T  ...                 NaN                   NaN
# 4768                 T  ...                 NaN                   NaN
# 4769                 T  ...                 NaN                   NaN
# 4770                 T  ...                 NaN                   NaN
# ...                ...  ...                 ...                   ...
# 403527               C  ...           -53.84333             -36.07833
# 403528               C  ...           -53.79000             -36.22000
# 403529               C  ...           -53.79000             -36.22000
# 403530               C  ...           -53.77167             -36.14833
# 403531               C  ...           -53.77167             -36.14833
#
#         latitude_fsr  longitude_fsr  latitude longitude notes  \
# 4766             NaN            NaN -60.78000 -56.08000   NaN
# 4767             NaN            NaN -60.80000 -56.08000   NaN
# 4768             NaN            NaN -60.85000 -56.10000   NaN
# 4769             NaN            NaN -60.78000 -56.05000   NaN
# 4770             NaN            NaN -60.98000 -56.20000   NaN
# ...              ...            ...       ...       ...   ...
# 403527           NaN            NaN -53.87167 -36.02333   NaN
# 403528           NaN            NaN -53.82167 -36.15333   NaN
# 403529           NaN            NaN -53.82167 -36.15333   NaN
# 403530           NaN            NaN -53.79000 -36.22000   NaN
# 403531           NaN            NaN -53.79000 -36.22000   NaN
#
#        krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h
# 4766               7260.000               0.416667               0.750000
# 4767               7920.000               0.750000               1.083333
# 4768               4692.000               1.583333               1.900000
# 4769               5896.000               2.583333               2.966667
# 4770                 88.000               1.500000               1.783333
# ...                     ...                    ...                    ...
# 403527             8643.049               2.000000               2.000000
# 403528             6630.144               2.000000               2.000000
# 403529             6630.144               2.000000               2.000000
# 403530             7514.163               2.000000               2.000000
# 403531             7514.163               2.000000               2.000000
#
# [397205 rows x 37 columns]

# %% [markdown]
# ### Extract the rows where start coordinates are not available (only the end point is known)

# %%
# check the NAN : some of the rows have a nan for the lat and long haul start 
# when only the set end lat and long are available, the data are treated like the 'day' aggregated data
# when start and end lat and long are available, then the procedure describe above is apply to assigned the catched biomass to the cells

# seclect the part of the dataset where lat-long of the start is non available:
unagg_data_NAN_start = unagg_data.loc[unagg_data['latitude_haul_start'].isna()]
unagg_data_NAN_start # 101677 rows

# here we remove the rows with these missing values - then this dataframe is used
unagg_data_noNAN = unagg_data.loc[unagg_data['latitude_haul_start'].notna()]
unagg_data_noNAN # 295528 rows

# 101677 + 295528 = 397205 (=nb of rows of unagg_data) OK
# Out:
#          c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 5699     30751          NaN             NaN              NaN          9.0
# 5700     30752          NaN             NaN              NaN         10.0
# 5701     30753          NaN             NaN              NaN         11.0
# 5702     30754          NaN             NaN              NaN         12.0
# 5703     30755          NaN             NaN              NaN         13.0
# ...        ...          ...             ...              ...          ...
# 403527  537073          NaN             NaN              NaN       4677.0
# 403528  537076          NaN             NaN              NaN       4680.0
# 403529  537077          NaN             NaN              NaN       4681.0
# 403530  537078          NaN             NaN              NaN       4682.0
# 403531  537079          NaN             NaN              NaN       4683.0
#
#        fishing_purpose_code  season_ccamlr target_species asd_code  \
# 5699                      C           1999            KRI      481
# 5700                      C           1999            KRI      481
# 5701                      C           1999            KRI      481
# 5702                      C           1999            KRI      481
# 5703                      C           1999            KRI      481
# ...                     ...            ...            ...      ...
# 403527                    C           2023            KRI      483
# 403528                    C           2023            KRI      483
# 403529                    C           2023            KRI      483
# 403530                    C           2023            KRI      483
# 403531                    C           2023            KRI      483
#
#        trawl_technique  ... latitude_haul_start  longitude_haul_start  \
# 5699                 T  ...           -62.67000             -58.72000
# 5700                 T  ...           -62.72000             -58.35000
# 5701                 T  ...           -62.68000             -58.53000
# 5702                 T  ...           -62.70000             -58.58000
# 5703                 T  ...           -62.70000             -58.48000
# ...                ...  ...                 ...                   ...
# 403527               C  ...           -53.84333             -36.07833
# 403528               C  ...           -53.79000             -36.22000
# 403529               C  ...           -53.79000             -36.22000
# 403530               C  ...           -53.77167             -36.14833
# 403531               C  ...           -53.77167             -36.14833
#
#         latitude_fsr  longitude_fsr  latitude longitude notes  \
# 5699             NaN            NaN -62.65000 -58.75000   NaN
# 5700             NaN            NaN -62.72000 -58.37000   NaN
# 5701             NaN            NaN -62.72000 -58.50000   NaN
# 5702             NaN            NaN -62.67000 -58.53000   NaN
# 5703             NaN            NaN -62.68000 -58.55000   NaN
# ...              ...            ...       ...       ...   ...
# 403527           NaN            NaN -53.87167 -36.02333   NaN
# 403528           NaN            NaN -53.82167 -36.15333   NaN
# 403529           NaN            NaN -53.82167 -36.15333   NaN
# 403530           NaN            NaN -53.79000 -36.22000   NaN
# 403531           NaN            NaN -53.79000 -36.22000   NaN
#
#        krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h
# 5699               8000.000               0.750000               1.500000
# 5700               8000.000               1.250000               4.333333
# 5701              15000.000               1.083333               1.916667
# 5702              20000.000               1.333333               2.000000
# 5703               6000.000               1.366667               2.083333
# ...                     ...                    ...                    ...
# 403527             8643.049               2.000000               2.000000
# 403528             6630.144               2.000000               2.000000
# 403529             6630.144               2.000000               2.000000
# 403530             7514.163               2.000000               2.000000
# 403531             7514.163               2.000000               2.000000
#
# [295528 rows x 37 columns]

# %%
## Assing the "latitude/longitude_fsr" with the same procedure than with 'day' aggregated data
unagg_data_NAN_start['longitude_fsr'] = unagg_data_NAN_start['longitude'].apply(round_longitude)
unagg_data_NAN_start['latitude_fsr'] = unagg_data_NAN_start['latitude'].apply(round_latitude)
unagg_data_NAN_start # 101677 rows × 37 columns
# Out:
# C:\Users\anael\AppData\Local\Temp\ipykernel_6844\1790933794.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unagg_data_NAN_start['longitude_fsr'] = unagg_data_NAN_start['longitude'].apply(round_longitude)
# C:\Users\anael\AppData\Local\Temp\ipykernel_6844\1790933794.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unagg_data_NAN_start['latitude_fsr'] = unagg_data_NAN_start['latitude'].apply(round_latitude)
#          c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 4766     26529          NaN             NaN              NaN          1.0
# 4767     26530          NaN             NaN              NaN          2.0
# 4768     26531          NaN             NaN              NaN          4.0
# 4769     26532          NaN             NaN              NaN          5.0
# 4770     26533          NaN             NaN              NaN          6.0
# ...        ...          ...             ...              ...          ...
# 118948  225411          NaN             NaN              NaN         42.0
# 118949  225412          NaN             NaN              NaN         43.0
# 118950  225413          NaN             NaN              NaN         44.0
# 118951  225414          NaN             NaN              NaN         45.0
# 118952  225416          NaN             NaN              NaN         47.0
#
#        fishing_purpose_code  season_ccamlr target_species asd_code  \
# 4766                      C           1998            KRI      481
# 4767                      C           1998            KRI      481
# 4768                      C           1998            KRI      481
# 4769                      C           1998            KRI      481
# 4770                      C           1998            KRI      481
# ...                     ...            ...            ...      ...
# 118948                    C           2005            KRI      481
# 118949                    C           2005            KRI      481
# 118950                    C           2005            KRI      481
# 118951                    C           2005            KRI      481
# 118952                    C           2005            KRI      481
#
#        trawl_technique  ... latitude_haul_start  longitude_haul_start  \
# 4766                 T  ...                 NaN                   NaN
# 4767                 T  ...                 NaN                   NaN
# 4768                 T  ...                 NaN                   NaN
# 4769                 T  ...                 NaN                   NaN
# 4770                 T  ...                 NaN                   NaN
# ...                ...  ...                 ...                   ...
# 118948               T  ...                 NaN                   NaN
# 118949               T  ...                 NaN                   NaN
# 118950               T  ...                 NaN                   NaN
# 118951               T  ...                 NaN                   NaN
# 118952               T  ...                 NaN                   NaN
#
#         latitude_fsr  longitude_fsr   latitude  longitude notes  \
# 4766          -60.75          -56.5 -60.780000 -56.080000   NaN
# 4767          -60.75          -56.5 -60.800000 -56.080000   NaN
# 4768          -60.75          -56.5 -60.850000 -56.100000   NaN
# 4769          -60.75          -56.5 -60.780000 -56.050000   NaN
# 4770          -60.75          -56.5 -60.980000 -56.200000   NaN
# ...              ...            ...        ...        ...   ...
# 118948        -62.25          -59.5 -62.150000 -59.916667   NaN
# 118949        -62.25          -59.5 -62.150000 -59.950000   NaN
# 118950        -62.25          -59.5 -62.166667 -59.900000   NaN
# 118951        -62.25          -59.5 -62.150000 -59.866667   NaN
# 118952        -62.25          -59.5 -62.183333 -59.940000   NaN
#
#        krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h
# 4766                 7260.0               0.416667               0.750000
# 4767                 7920.0               0.750000               1.083333
# 4768                 4692.0               1.583333               1.900000
# 4769                 5896.0               2.583333               2.966667
# 4770                   88.0               1.500000               1.783333
# ...                     ...                    ...                    ...
# 118948              10000.0               1.000000               1.500000
# 118949               6000.0               1.000000               1.500000
# 118950               2000.0               1.000000               1.583333
# 118951               5000.0               1.000000               1.583333
# 118952               3000.0               0.666667               1.166667
#
# [101677 rows x 37 columns]

# %%
# merge these data with the aggregated data 
agg_data = pd.concat([agg_data, unagg_data_NAN_start])
agg_data.shape # (108004, 37)
# Out:
# (108004, 37)

# %% [markdown]
# ### Applied conditions on the start end end latitude and longitude to distinguish the tows straddling on two different cells
#
# Formalisation of the conditions to separate the two different cases explained above:
#
# The whole biomass is attributed to the cell of coordinates longitude x and latitude y IF:
#
# - the longitude of the start and the longitude of the end is on the same cell => **the integer part(long_start) == the integer part(long_end)**
#
#
# AND
#
#
# - the latitude of the start and the latitude of the end is on the same cell => **the integer part(lat_start) == the integer part(lat_start)** AND **the decimal part(lat_start) AND the decimal part(lat_end) >= 0.5 OR both < 0.5**

# %%
# condition on longitude
condition_long = np.trunc(unagg_data_noNAN.longitude_haul_start) == np.trunc(unagg_data_noNAN.longitude_set_end)
condition_long
# Out:
# 5699      True
# 5700      True
# 5701      True
# 5702      True
# 5703      True
#           ...
# 403527    True
# 403528    True
# 403529    True
# 403530    True
# 403531    True
# Length: 295528, dtype: bool

# %%
#conditions on latitude
condition_lat1 = (np.trunc(unagg_data_noNAN.latitude_haul_start) == np.trunc(unagg_data_noNAN.latitude_set_end)) 
condition_lat1
# Out:
# 5699      True
# 5700      True
# 5701      True
# 5702      True
# 5703      True
#           ...
# 403527    True
# 403528    True
# 403529    True
# 403530    True
# 403531    True
# Length: 295528, dtype: bool

# %%
condition_lat2 = ((np.trunc(unagg_data_noNAN.latitude_haul_start) - unagg_data_noNAN.latitude_haul_start) < 0.5) & ((np.trunc(unagg_data_noNAN.latitude_set_end) - unagg_data_noNAN.latitude_set_end) < 0.5 )
condition_lat2
# Out:
# 5699      False
# 5700      False
# 5701      False
# 5702      False
# 5703      False
#           ...
# 403527    False
# 403528    False
# 403529    False
# 403530    False
# 403531    False
# Length: 295528, dtype: bool

# %%
condition_lat3 = ((np.trunc(unagg_data_noNAN.latitude_haul_start) - unagg_data_noNAN.latitude_haul_start) >= 0.5) & ((np.trunc(unagg_data_noNAN.latitude_set_end) - unagg_data_noNAN.latitude_set_end)>= 0.5)
condition_lat3
# Out:
# 5699      True
# 5700      True
# 5701      True
# 5702      True
# 5703      True
#           ...
# 403527    True
# 403528    True
# 403529    True
# 403530    True
# 403531    True
# Length: 295528, dtype: bool

# %%
condition_lat = condition_lat1 & condition_lat2 | condition_lat3
condition_lat
# Out:
# 5699      True
# 5700      True
# 5701      True
# 5702      True
# 5703      True
#           ...
# 403527    True
# 403528    True
# 403529    True
# 403530    True
# 403531    True
# Length: 295528, dtype: bool

# %% [markdown]
# ### test condition par condition
# A short test condition by condition to check how many rows are removed from each conditions.

# %%
#subset of the data where condition on longitude is verified
unagg_data_cond_long = unagg_data_noNAN.loc[condition_long]
unagg_data_cond_long # 280739 (but 295528 in unagg_data_noNAN => -14789)
# Out:
#          c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 5699     30751          NaN             NaN              NaN          9.0
# 5700     30752          NaN             NaN              NaN         10.0
# 5701     30753          NaN             NaN              NaN         11.0
# 5702     30754          NaN             NaN              NaN         12.0
# 5703     30755          NaN             NaN              NaN         13.0
# ...        ...          ...             ...              ...          ...
# 403527  537073          NaN             NaN              NaN       4677.0
# 403528  537076          NaN             NaN              NaN       4680.0
# 403529  537077          NaN             NaN              NaN       4681.0
# 403530  537078          NaN             NaN              NaN       4682.0
# 403531  537079          NaN             NaN              NaN       4683.0
#
#        fishing_purpose_code  season_ccamlr target_species asd_code  \
# 5699                      C           1999            KRI      481
# 5700                      C           1999            KRI      481
# 5701                      C           1999            KRI      481
# 5702                      C           1999            KRI      481
# 5703                      C           1999            KRI      481
# ...                     ...            ...            ...      ...
# 403527                    C           2023            KRI      483
# 403528                    C           2023            KRI      483
# 403529                    C           2023            KRI      483
# 403530                    C           2023            KRI      483
# 403531                    C           2023            KRI      483
#
#        trawl_technique  ... latitude_haul_start  longitude_haul_start  \
# 5699                 T  ...           -62.67000             -58.72000
# 5700                 T  ...           -62.72000             -58.35000
# 5701                 T  ...           -62.68000             -58.53000
# 5702                 T  ...           -62.70000             -58.58000
# 5703                 T  ...           -62.70000             -58.48000
# ...                ...  ...                 ...                   ...
# 403527               C  ...           -53.84333             -36.07833
# 403528               C  ...           -53.79000             -36.22000
# 403529               C  ...           -53.79000             -36.22000
# 403530               C  ...           -53.77167             -36.14833
# 403531               C  ...           -53.77167             -36.14833
#
#         latitude_fsr  longitude_fsr  latitude longitude notes  \
# 5699             NaN            NaN -62.65000 -58.75000   NaN
# 5700             NaN            NaN -62.72000 -58.37000   NaN
# 5701             NaN            NaN -62.72000 -58.50000   NaN
# 5702             NaN            NaN -62.67000 -58.53000   NaN
# 5703             NaN            NaN -62.68000 -58.55000   NaN
# ...              ...            ...       ...       ...   ...
# 403527           NaN            NaN -53.87167 -36.02333   NaN
# 403528           NaN            NaN -53.82167 -36.15333   NaN
# 403529           NaN            NaN -53.82167 -36.15333   NaN
# 403530           NaN            NaN -53.79000 -36.22000   NaN
# 403531           NaN            NaN -53.79000 -36.22000   NaN
#
#        krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h
# 5699               8000.000               0.750000               1.500000
# 5700               8000.000               1.250000               4.333333
# 5701              15000.000               1.083333               1.916667
# 5702              20000.000               1.333333               2.000000
# 5703               6000.000               1.366667               2.083333
# ...                     ...                    ...                    ...
# 403527             8643.049               2.000000               2.000000
# 403528             6630.144               2.000000               2.000000
# 403529             6630.144               2.000000               2.000000
# 403530             7514.163               2.000000               2.000000
# 403531             7514.163               2.000000               2.000000
#
# [280739 rows x 37 columns]

# %%
#subset of the data where condition on latitude is verified
unagg_data_cond_lat = unagg_data_noNAN.loc[condition_lat]
unagg_data_cond_lat # 282625 ( -12903)
# Out:
#          c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 5699     30751          NaN             NaN              NaN          9.0
# 5700     30752          NaN             NaN              NaN         10.0
# 5701     30753          NaN             NaN              NaN         11.0
# 5702     30754          NaN             NaN              NaN         12.0
# 5703     30755          NaN             NaN              NaN         13.0
# ...        ...          ...             ...              ...          ...
# 403527  537073          NaN             NaN              NaN       4677.0
# 403528  537076          NaN             NaN              NaN       4680.0
# 403529  537077          NaN             NaN              NaN       4681.0
# 403530  537078          NaN             NaN              NaN       4682.0
# 403531  537079          NaN             NaN              NaN       4683.0
#
#        fishing_purpose_code  season_ccamlr target_species asd_code  \
# 5699                      C           1999            KRI      481
# 5700                      C           1999            KRI      481
# 5701                      C           1999            KRI      481
# 5702                      C           1999            KRI      481
# 5703                      C           1999            KRI      481
# ...                     ...            ...            ...      ...
# 403527                    C           2023            KRI      483
# 403528                    C           2023            KRI      483
# 403529                    C           2023            KRI      483
# 403530                    C           2023            KRI      483
# 403531                    C           2023            KRI      483
#
#        trawl_technique  ... latitude_haul_start  longitude_haul_start  \
# 5699                 T  ...           -62.67000             -58.72000
# 5700                 T  ...           -62.72000             -58.35000
# 5701                 T  ...           -62.68000             -58.53000
# 5702                 T  ...           -62.70000             -58.58000
# 5703                 T  ...           -62.70000             -58.48000
# ...                ...  ...                 ...                   ...
# 403527               C  ...           -53.84333             -36.07833
# 403528               C  ...           -53.79000             -36.22000
# 403529               C  ...           -53.79000             -36.22000
# 403530               C  ...           -53.77167             -36.14833
# 403531               C  ...           -53.77167             -36.14833
#
#         latitude_fsr  longitude_fsr  latitude longitude notes  \
# 5699             NaN            NaN -62.65000 -58.75000   NaN
# 5700             NaN            NaN -62.72000 -58.37000   NaN
# 5701             NaN            NaN -62.72000 -58.50000   NaN
# 5702             NaN            NaN -62.67000 -58.53000   NaN
# 5703             NaN            NaN -62.68000 -58.55000   NaN
# ...              ...            ...       ...       ...   ...
# 403527           NaN            NaN -53.87167 -36.02333   NaN
# 403528           NaN            NaN -53.82167 -36.15333   NaN
# 403529           NaN            NaN -53.82167 -36.15333   NaN
# 403530           NaN            NaN -53.79000 -36.22000   NaN
# 403531           NaN            NaN -53.79000 -36.22000   NaN
#
#        krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h
# 5699               8000.000               0.750000               1.500000
# 5700               8000.000               1.250000               4.333333
# 5701              15000.000               1.083333               1.916667
# 5702              20000.000               1.333333               2.000000
# 5703               6000.000               1.366667               2.083333
# ...                     ...                    ...                    ...
# 403527             8643.049               2.000000               2.000000
# 403528             6630.144               2.000000               2.000000
# 403529             6630.144               2.000000               2.000000
# 403530             7514.163               2.000000               2.000000
# 403531             7514.163               2.000000               2.000000
#
# [282625 rows x 37 columns]

# %% [markdown]
# ## Condition both on latitude and longitude

# %%
condition = condition_long & condition_lat
condition
# Out:
# 5699      True
# 5700      True
# 5701      True
# 5702      True
# 5703      True
#           ...
# 403527    True
# 403528    True
# 403529    True
# 403530    True
# 403531    True
# Length: 295528, dtype: bool

# %% [markdown]
# #### The subset that is respecting the conditon : no straddling

# %%
# create the subset of the data that is the data on haul basis where the entire tow is in the same cell
unagg_data_cond = unagg_data_noNAN.loc[condition]
unagg_data_cond # 268399  (-27129)
# Out:
#          c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 5699     30751          NaN             NaN              NaN          9.0
# 5700     30752          NaN             NaN              NaN         10.0
# 5701     30753          NaN             NaN              NaN         11.0
# 5702     30754          NaN             NaN              NaN         12.0
# 5703     30755          NaN             NaN              NaN         13.0
# ...        ...          ...             ...              ...          ...
# 403527  537073          NaN             NaN              NaN       4677.0
# 403528  537076          NaN             NaN              NaN       4680.0
# 403529  537077          NaN             NaN              NaN       4681.0
# 403530  537078          NaN             NaN              NaN       4682.0
# 403531  537079          NaN             NaN              NaN       4683.0
#
#        fishing_purpose_code  season_ccamlr target_species asd_code  \
# 5699                      C           1999            KRI      481
# 5700                      C           1999            KRI      481
# 5701                      C           1999            KRI      481
# 5702                      C           1999            KRI      481
# 5703                      C           1999            KRI      481
# ...                     ...            ...            ...      ...
# 403527                    C           2023            KRI      483
# 403528                    C           2023            KRI      483
# 403529                    C           2023            KRI      483
# 403530                    C           2023            KRI      483
# 403531                    C           2023            KRI      483
#
#        trawl_technique  ... latitude_haul_start  longitude_haul_start  \
# 5699                 T  ...           -62.67000             -58.72000
# 5700                 T  ...           -62.72000             -58.35000
# 5701                 T  ...           -62.68000             -58.53000
# 5702                 T  ...           -62.70000             -58.58000
# 5703                 T  ...           -62.70000             -58.48000
# ...                ...  ...                 ...                   ...
# 403527               C  ...           -53.84333             -36.07833
# 403528               C  ...           -53.79000             -36.22000
# 403529               C  ...           -53.79000             -36.22000
# 403530               C  ...           -53.77167             -36.14833
# 403531               C  ...           -53.77167             -36.14833
#
#         latitude_fsr  longitude_fsr  latitude longitude notes  \
# 5699             NaN            NaN -62.65000 -58.75000   NaN
# 5700             NaN            NaN -62.72000 -58.37000   NaN
# 5701             NaN            NaN -62.72000 -58.50000   NaN
# 5702             NaN            NaN -62.67000 -58.53000   NaN
# 5703             NaN            NaN -62.68000 -58.55000   NaN
# ...              ...            ...       ...       ...   ...
# 403527           NaN            NaN -53.87167 -36.02333   NaN
# 403528           NaN            NaN -53.82167 -36.15333   NaN
# 403529           NaN            NaN -53.82167 -36.15333   NaN
# 403530           NaN            NaN -53.79000 -36.22000   NaN
# 403531           NaN            NaN -53.79000 -36.22000   NaN
#
#        krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h
# 5699               8000.000               0.750000               1.500000
# 5700               8000.000               1.250000               4.333333
# 5701              15000.000               1.083333               1.916667
# 5702              20000.000               1.333333               2.000000
# 5703               6000.000               1.366667               2.083333
# ...                     ...                    ...                    ...
# 403527             8643.049               2.000000               2.000000
# 403528             6630.144               2.000000               2.000000
# 403529             6630.144               2.000000               2.000000
# 403530             7514.163               2.000000               2.000000
# 403531             7514.163               2.000000               2.000000
#
# [268399 rows x 37 columns]

# %%
## For the unagg_data_cond
unagg_data_cond['longitude_fsr'] = unagg_data_cond['longitude'].apply(round_longitude)
unagg_data_cond['latitude_fsr'] = unagg_data_cond['latitude'].apply(round_latitude)
unagg_data_cond
# Out:
# C:\Users\anael\AppData\Local\Temp\ipykernel_6844\2383067816.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unagg_data_cond['longitude_fsr'] = unagg_data_cond['longitude'].apply(round_longitude)
# C:\Users\anael\AppData\Local\Temp\ipykernel_6844\2383067816.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unagg_data_cond['latitude_fsr'] = unagg_data_cond['latitude'].apply(round_latitude)
#          c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 5699     30751          NaN             NaN              NaN          9.0
# 5700     30752          NaN             NaN              NaN         10.0
# 5701     30753          NaN             NaN              NaN         11.0
# 5702     30754          NaN             NaN              NaN         12.0
# 5703     30755          NaN             NaN              NaN         13.0
# ...        ...          ...             ...              ...          ...
# 403527  537073          NaN             NaN              NaN       4677.0
# 403528  537076          NaN             NaN              NaN       4680.0
# 403529  537077          NaN             NaN              NaN       4681.0
# 403530  537078          NaN             NaN              NaN       4682.0
# 403531  537079          NaN             NaN              NaN       4683.0
#
#        fishing_purpose_code  season_ccamlr target_species asd_code  \
# 5699                      C           1999            KRI      481
# 5700                      C           1999            KRI      481
# 5701                      C           1999            KRI      481
# 5702                      C           1999            KRI      481
# 5703                      C           1999            KRI      481
# ...                     ...            ...            ...      ...
# 403527                    C           2023            KRI      483
# 403528                    C           2023            KRI      483
# 403529                    C           2023            KRI      483
# 403530                    C           2023            KRI      483
# 403531                    C           2023            KRI      483
#
#        trawl_technique  ... latitude_haul_start  longitude_haul_start  \
# 5699                 T  ...           -62.67000             -58.72000
# 5700                 T  ...           -62.72000             -58.35000
# 5701                 T  ...           -62.68000             -58.53000
# 5702                 T  ...           -62.70000             -58.58000
# 5703                 T  ...           -62.70000             -58.48000
# ...                ...  ...                 ...                   ...
# 403527               C  ...           -53.84333             -36.07833
# 403528               C  ...           -53.79000             -36.22000
# 403529               C  ...           -53.79000             -36.22000
# 403530               C  ...           -53.77167             -36.14833
# 403531               C  ...           -53.77167             -36.14833
#
#         latitude_fsr  longitude_fsr  latitude longitude notes  \
# 5699          -62.75          -58.5 -62.65000 -58.75000   NaN
# 5700          -62.75          -58.5 -62.72000 -58.37000   NaN
# 5701          -62.75          -58.5 -62.72000 -58.50000   NaN
# 5702          -62.75          -58.5 -62.67000 -58.53000   NaN
# 5703          -62.75          -58.5 -62.68000 -58.55000   NaN
# ...              ...            ...       ...       ...   ...
# 403527        -53.75          -36.5 -53.87167 -36.02333   NaN
# 403528        -53.75          -36.5 -53.82167 -36.15333   NaN
# 403529        -53.75          -36.5 -53.82167 -36.15333   NaN
# 403530        -53.75          -36.5 -53.79000 -36.22000   NaN
# 403531        -53.75          -36.5 -53.79000 -36.22000   NaN
#
#        krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h
# 5699               8000.000               0.750000               1.500000
# 5700               8000.000               1.250000               4.333333
# 5701              15000.000               1.083333               1.916667
# 5702              20000.000               1.333333               2.000000
# 5703               6000.000               1.366667               2.083333
# ...                     ...                    ...                    ...
# 403527             8643.049               2.000000               2.000000
# 403528             6630.144               2.000000               2.000000
# 403529             6630.144               2.000000               2.000000
# 403530             7514.163               2.000000               2.000000
# 403531             7514.163               2.000000               2.000000
#
# [268399 rows x 37 columns]

# %%
# concatenate witht the rest of the dataset 
agg_data = pd.concat([agg_data, unagg_data_cond])
agg_data.shape # (376403, 37)
# Out:
# (376403, 37)

# %% [markdown]
# #### The subset of the data that is not respecting the condition : straddling between cells

# %%
# create the subset of the dataset where the tows cross only the latitude border of a cell, only the longitude border of a cell or both
# use antijoin to have the subset of the data where the conditon is not verified
#separate the cases when the longitude border is crossed or latitude or both

outer_lat = unagg_data_noNAN.merge(unagg_data_cond_lat, how = 'outer', indicator = True)
crossing_lat = outer_lat[(outer_lat._merge == 'left_only')].drop('_merge', axis =1) # 12903 

outer_long = unagg_data_noNAN.merge(unagg_data_cond_long, how = 'outer', indicator = True)
crossing_long = outer_long[(outer_long._merge == 'left_only')].drop('_merge', axis =1) # 14789 

# crossing both lat and long borders
crossing_both = pd.merge(crossing_lat, crossing_long, how = 'inner') # 563

# %%
# removing the 'both' from the lat and long crossing to have the cases where ONLY the latitude or the longitude is crossed
outer = crossing_lat.merge(crossing_both, how='outer', indicator=True)
crossing_lat_only = outer[(outer._merge=='left_only')].drop('_merge', axis=1)
crossing_lat_only #12903-12340 = 563 OK

outer = crossing_long.merge(crossing_both, how='outer', indicator=True)
crossing_long_only = outer[(outer._merge=='left_only')].drop('_merge', axis=1)
crossing_long_only # 14789- 14226 = 563 OK
# Out:
#         c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 0       30767          NaN             NaN              NaN         25.0
# 1       30768          NaN             NaN              NaN         26.0
# 2       30792          NaN             NaN              NaN         50.0
# 3       30894          NaN             NaN              NaN        152.0
# 4       30896          NaN             NaN              NaN        154.0
# ...       ...          ...             ...              ...          ...
# 14784  537053          NaN             NaN              NaN       4657.0
# 14785  537060          NaN             NaN              NaN       4664.0
# 14786  537061          NaN             NaN              NaN       4665.0
# 14787  537062          NaN             NaN              NaN       4666.0
# 14788  537063          NaN             NaN              NaN       4667.0
#
#       fishing_purpose_code  season_ccamlr target_species asd_code  \
# 0                        C           1999            KRI      481
# 1                        C           1999            KRI      481
# 2                        C           1999            KRI      481
# 3                        C           1999            KRI      481
# 4                        C           1999            KRI      481
# ...                    ...            ...            ...      ...
# 14784                    C           2023            KRI      483
# 14785                    C           2023            KRI      483
# 14786                    C           2023            KRI      483
# 14787                    C           2023            KRI      483
# 14788                    C           2023            KRI      483
#
#       trawl_technique  ... latitude_haul_start  longitude_haul_start  \
# 0                   T  ...           -61.68000             -56.97000
# 1                   T  ...           -61.67000             -56.97000
# 2                   T  ...           -61.75000             -57.98000
# 3                   T  ...           -61.65000             -58.03000
# 4                   T  ...           -61.65000             -57.98000
# ...               ...  ...                 ...                   ...
# 14784               C  ...           -53.88000             -36.02333
# 14785               C  ...           -53.86167             -35.99500
# 14786               C  ...           -53.86167             -35.99500
# 14787               C  ...           -53.88333             -36.02000
# 14788               C  ...           -53.88333             -36.02000
#
#        latitude_fsr  longitude_fsr  latitude longitude notes  \
# 0               NaN            NaN -61.70000 -57.00000   NaN
# 1               NaN            NaN -61.67000 -57.12000   NaN
# 2               NaN            NaN -61.75000 -58.15000   NaN
# 3               NaN            NaN -61.63000 -57.97000   NaN
# 4               NaN            NaN -61.65000 -58.08000   NaN
# ...             ...            ...       ...       ...   ...
# 14784           NaN            NaN -53.85167 -35.99000   NaN
# 14785           NaN            NaN -53.87667 -36.03667   NaN
# 14786           NaN            NaN -53.87667 -36.03667   NaN
# 14787           NaN            NaN -53.86167 -35.99500   NaN
# 14788           NaN            NaN -53.86167 -35.99500   NaN
#
#       krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h
# 0                  3000.00               2.333333               3.000000
# 1                  2000.00               0.500000               1.166667
# 2                 15000.00               0.583333               1.666667
# 3                  5000.00               1.583333               2.533333
# 4                  4000.00                    NaN               2.666667
# ...                    ...                    ...                    ...
# 14784             29944.82               2.000000               2.000000
# 14785             16785.11               2.000000               2.000000
# 14786             16785.11               2.000000               2.000000
# 14787             33116.40               1.983333               1.983333
# 14788             33116.40               1.983333               1.983333
#
# [14226 rows x 37 columns]

# %%
crossing_lat_only
# Out:
#         c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 0       30777          NaN             NaN              NaN         35.0
# 1       31336          NaN             NaN              NaN        158.0
# 2       31355          NaN             NaN              NaN        177.0
# 3       31379          NaN             NaN              NaN        201.0
# 4       31380          NaN             NaN              NaN        202.0
# ...       ...          ...             ...              ...          ...
# 12898  534660     347043.0          2413.0           1768.0       1768.0
# 12899  534661     347044.0          2413.0           1769.0       1769.0
# 12900  534664     347047.0          2413.0           1772.0       1772.0
# 12901  536334          NaN             NaN              NaN       3790.0
# 12902  536335          NaN             NaN              NaN       3791.0
#
#       fishing_purpose_code  season_ccamlr target_species asd_code  \
# 0                        C           1999            KRI      481
# 1                        C           1999            KRI      482
# 2                        C           1999            KRI      482
# 3                        C           1999            KRI      482
# 4                        C           1999            KRI      482
# ...                    ...            ...            ...      ...
# 12898                    C           2023            KRI      483
# 12899                    C           2023            KRI      483
# 12900                    C           2023            KRI      483
# 12901                    C           2023            KRI      483
# 12902                    C           2023            KRI      483
#
#       trawl_technique  ... latitude_haul_start  longitude_haul_start  \
# 0                   T  ...           -62.00000             -57.23000
# 1                   T  ...           -60.52000             -46.32000
# 2                   T  ...           -60.45000             -46.37000
# 3                   T  ...           -60.50000             -46.48000
# 4                   T  ...           -60.38000             -46.50000
# ...               ...  ...                 ...                   ...
# 12898               T  ...           -54.00400             -35.61883
# 12899               T  ...           -53.99117             -35.64083
# 12900               T  ...           -54.00083             -35.61883
# 12901               C  ...           -53.51833             -36.53167
# 12902               C  ...           -53.51833             -36.53167
#
#        latitude_fsr  longitude_fsr  latitude longitude notes  \
# 0               NaN            NaN -61.93000 -57.22000   NaN
# 1               NaN            NaN -60.48000 -46.27000   NaN
# 2               NaN            NaN -60.50000 -46.37000   NaN
# 3               NaN            NaN -60.45000 -46.40000   NaN
# 4               NaN            NaN -60.58000 -46.50000   NaN
# ...             ...            ...       ...       ...   ...
# 12898           NaN            NaN -53.99283 -35.64667   NaN
# 12899           NaN            NaN -54.00617 -35.61700   NaN
# 12900           NaN            NaN -53.99417 -35.62700   NaN
# 12901           NaN            NaN -53.49667 -36.45667   NaN
# 12902           NaN            NaN -53.49667 -36.45667   NaN
#
#       krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h
# 0              2000.000000               1.083333               2.016667
# 1             15000.000000               1.000000               1.583333
# 2              8000.000000               0.916667               1.416667
# 3             10000.000000               0.916667               1.583333
# 4              6000.000000               1.083333               1.666667
# ...                    ...                    ...                    ...
# 12898         20518.570000               0.500000               0.916667
# 12899         21565.420000               0.500000               1.000000
# 12900         21565.420000               0.250000               0.666667
# 12901             4.882888               2.000000               2.000000
# 12902             4.882888               2.000000               2.000000
#
# [12340 rows x 37 columns]

# %% [markdown]
# #### Assigne the cells coordinates "fsr" and the krill biomass
#
# - For the **tows thar are not straddling between cells ("unagg_data_cond" dataset)**, just assigned the cells coorindates at latitude-frs and longitude-fsr, rounding the latitude and longitude coordinates (end point of the tow) the nearest rectangles mid-point (same procedure as for day aggregated data).
#
# - For the **straddling data**, created the same dataset with the latitude-fsr and longitude-fsr calculated from rounding either the start point or the end point of the tow. Then concatenate the datasets.

# %% [markdown]
# #### Subset when tows are straddling several cells

# %%
## For the straddling data on LATITUDE
# create 2 datasets where frs coordinates are one of the two cells that a tow crosses 
# then we can concatenate them (=> 1 row in the original dataset becomes two rows in the final one)

crossing_lat_s = crossing_lat_only.drop(columns=['longitude_fsr', 'latitude_fsr']) # with strating point 
crossing_lat_s['longitude_fsr'] = crossing_lat_s['longitude_haul_start'].apply(round_longitude)
crossing_lat_s['latitude_fsr'] = crossing_lat_s['latitude_haul_start'].apply(round_latitude)

crossing_lat_e = crossing_lat_only.drop(columns=['longitude_fsr', 'latitude_fsr']) # with ending point
crossing_lat_e['longitude_fsr'] = crossing_lat_e['longitude'].apply(round_longitude)
crossing_lat_e['latitude_fsr'] = crossing_lat_e['latitude'].apply(round_latitude)

# %%
crossing_lat_s
# Out:
#         c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 0       30777          NaN             NaN              NaN         35.0
# 1       31336          NaN             NaN              NaN        158.0
# 2       31355          NaN             NaN              NaN        177.0
# 3       31379          NaN             NaN              NaN        201.0
# 4       31380          NaN             NaN              NaN        202.0
# ...       ...          ...             ...              ...          ...
# 12898  534660     347043.0          2413.0           1768.0       1768.0
# 12899  534661     347044.0          2413.0           1769.0       1769.0
# 12900  534664     347047.0          2413.0           1772.0       1772.0
# 12901  536334          NaN             NaN              NaN       3790.0
# 12902  536335          NaN             NaN              NaN       3791.0
#
#       fishing_purpose_code  season_ccamlr target_species asd_code  \
# 0                        C           1999            KRI      481
# 1                        C           1999            KRI      482
# 2                        C           1999            KRI      482
# 3                        C           1999            KRI      482
# 4                        C           1999            KRI      482
# ...                    ...            ...            ...      ...
# 12898                    C           2023            KRI      483
# 12899                    C           2023            KRI      483
# 12900                    C           2023            KRI      483
# 12901                    C           2023            KRI      483
# 12902                    C           2023            KRI      483
#
#       trawl_technique  ... latitude_haul_start  longitude_haul_start  \
# 0                   T  ...           -62.00000             -57.23000
# 1                   T  ...           -60.52000             -46.32000
# 2                   T  ...           -60.45000             -46.37000
# 3                   T  ...           -60.50000             -46.48000
# 4                   T  ...           -60.38000             -46.50000
# ...               ...  ...                 ...                   ...
# 12898               T  ...           -54.00400             -35.61883
# 12899               T  ...           -53.99117             -35.64083
# 12900               T  ...           -54.00083             -35.61883
# 12901               C  ...           -53.51833             -36.53167
# 12902               C  ...           -53.51833             -36.53167
#
#        latitude  longitude  notes krill_greenweight_kg trawl_duration_depth_h  \
# 0     -61.93000  -57.22000    NaN          2000.000000               1.083333
# 1     -60.48000  -46.27000    NaN         15000.000000               1.000000
# 2     -60.50000  -46.37000    NaN          8000.000000               0.916667
# 3     -60.45000  -46.40000    NaN         10000.000000               0.916667
# 4     -60.58000  -46.50000    NaN          6000.000000               1.083333
# ...         ...        ...    ...                  ...                    ...
# 12898 -53.99283  -35.64667    NaN         20518.570000               0.500000
# 12899 -54.00617  -35.61700    NaN         21565.420000               0.500000
# 12900 -53.99417  -35.62700    NaN         21565.420000               0.250000
# 12901 -53.49667  -36.45667    NaN             4.882888               2.000000
# 12902 -53.49667  -36.45667    NaN             4.882888               2.000000
#
#       trawl_duration_total_h longitude_fsr latitude_fsr
# 0                   2.016667         -57.5       -62.25
# 1                   1.583333         -46.5       -60.75
# 2                   1.416667         -46.5       -60.25
# 3                   1.583333         -46.5       -60.75
# 4                   1.666667         -46.5       -60.25
# ...                      ...           ...          ...
# 12898               0.916667         -35.5       -54.25
# 12899               1.000000         -35.5       -53.75
# 12900               0.666667         -35.5       -54.25
# 12901               2.000000         -36.5       -53.75
# 12902               2.000000         -36.5       -53.75
#
# [12340 rows x 37 columns]

# %%
crossing_lat_e
# Out:
#         c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 0       30777          NaN             NaN              NaN         35.0
# 1       31336          NaN             NaN              NaN        158.0
# 2       31355          NaN             NaN              NaN        177.0
# 3       31379          NaN             NaN              NaN        201.0
# 4       31380          NaN             NaN              NaN        202.0
# ...       ...          ...             ...              ...          ...
# 12898  534660     347043.0          2413.0           1768.0       1768.0
# 12899  534661     347044.0          2413.0           1769.0       1769.0
# 12900  534664     347047.0          2413.0           1772.0       1772.0
# 12901  536334          NaN             NaN              NaN       3790.0
# 12902  536335          NaN             NaN              NaN       3791.0
#
#       fishing_purpose_code  season_ccamlr target_species asd_code  \
# 0                        C           1999            KRI      481
# 1                        C           1999            KRI      482
# 2                        C           1999            KRI      482
# 3                        C           1999            KRI      482
# 4                        C           1999            KRI      482
# ...                    ...            ...            ...      ...
# 12898                    C           2023            KRI      483
# 12899                    C           2023            KRI      483
# 12900                    C           2023            KRI      483
# 12901                    C           2023            KRI      483
# 12902                    C           2023            KRI      483
#
#       trawl_technique  ... latitude_haul_start  longitude_haul_start  \
# 0                   T  ...           -62.00000             -57.23000
# 1                   T  ...           -60.52000             -46.32000
# 2                   T  ...           -60.45000             -46.37000
# 3                   T  ...           -60.50000             -46.48000
# 4                   T  ...           -60.38000             -46.50000
# ...               ...  ...                 ...                   ...
# 12898               T  ...           -54.00400             -35.61883
# 12899               T  ...           -53.99117             -35.64083
# 12900               T  ...           -54.00083             -35.61883
# 12901               C  ...           -53.51833             -36.53167
# 12902               C  ...           -53.51833             -36.53167
#
#        latitude  longitude  notes krill_greenweight_kg trawl_duration_depth_h  \
# 0     -61.93000  -57.22000    NaN          2000.000000               1.083333
# 1     -60.48000  -46.27000    NaN         15000.000000               1.000000
# 2     -60.50000  -46.37000    NaN          8000.000000               0.916667
# 3     -60.45000  -46.40000    NaN         10000.000000               0.916667
# 4     -60.58000  -46.50000    NaN          6000.000000               1.083333
# ...         ...        ...    ...                  ...                    ...
# 12898 -53.99283  -35.64667    NaN         20518.570000               0.500000
# 12899 -54.00617  -35.61700    NaN         21565.420000               0.500000
# 12900 -53.99417  -35.62700    NaN         21565.420000               0.250000
# 12901 -53.49667  -36.45667    NaN             4.882888               2.000000
# 12902 -53.49667  -36.45667    NaN             4.882888               2.000000
#
#       trawl_duration_total_h longitude_fsr latitude_fsr
# 0                   2.016667         -57.5       -61.75
# 1                   1.583333         -46.5       -60.25
# 2                   1.416667         -46.5       -60.75
# 3                   1.583333         -46.5       -60.25
# 4                   1.666667         -46.5       -60.75
# ...                      ...           ...          ...
# 12898               0.916667         -35.5       -53.75
# 12899               1.000000         -35.5       -54.25
# 12900               0.666667         -35.5       -53.75
# 12901               2.000000         -36.5       -53.25
# 12902               2.000000         -36.5       -53.25
#
# [12340 rows x 37 columns]

# %%
## For the straddling data on LONGITUDE
# create 2 datasets where frs coordinates are one of the two cells that a tow crosses 
# then we can concatenate them (=> 1 row in the original dataset becomes two rows in the final one)

crossing_long_s = crossing_long_only.drop(columns=['longitude_fsr', 'latitude_fsr']) # with strating point 
crossing_long_s['longitude_fsr'] = crossing_long_s['longitude_haul_start'].apply(round_longitude)
crossing_long_s['latitude_fsr'] = crossing_long_s['latitude_haul_start'].apply(round_latitude)

crossing_long_e = crossing_long_only.drop(columns=['longitude_fsr', 'latitude_fsr']) # with ending point
crossing_long_e['longitude_fsr'] = crossing_long_e['longitude'].apply(round_longitude)
crossing_long_e['latitude_fsr'] = crossing_long_e['latitude'].apply(round_latitude)

# %%
crossing_long_only
# Out:
#         c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 0       30767          NaN             NaN              NaN         25.0
# 1       30768          NaN             NaN              NaN         26.0
# 2       30792          NaN             NaN              NaN         50.0
# 3       30894          NaN             NaN              NaN        152.0
# 4       30896          NaN             NaN              NaN        154.0
# ...       ...          ...             ...              ...          ...
# 14784  537053          NaN             NaN              NaN       4657.0
# 14785  537060          NaN             NaN              NaN       4664.0
# 14786  537061          NaN             NaN              NaN       4665.0
# 14787  537062          NaN             NaN              NaN       4666.0
# 14788  537063          NaN             NaN              NaN       4667.0
#
#       fishing_purpose_code  season_ccamlr target_species asd_code  \
# 0                        C           1999            KRI      481
# 1                        C           1999            KRI      481
# 2                        C           1999            KRI      481
# 3                        C           1999            KRI      481
# 4                        C           1999            KRI      481
# ...                    ...            ...            ...      ...
# 14784                    C           2023            KRI      483
# 14785                    C           2023            KRI      483
# 14786                    C           2023            KRI      483
# 14787                    C           2023            KRI      483
# 14788                    C           2023            KRI      483
#
#       trawl_technique  ... latitude_haul_start  longitude_haul_start  \
# 0                   T  ...           -61.68000             -56.97000
# 1                   T  ...           -61.67000             -56.97000
# 2                   T  ...           -61.75000             -57.98000
# 3                   T  ...           -61.65000             -58.03000
# 4                   T  ...           -61.65000             -57.98000
# ...               ...  ...                 ...                   ...
# 14784               C  ...           -53.88000             -36.02333
# 14785               C  ...           -53.86167             -35.99500
# 14786               C  ...           -53.86167             -35.99500
# 14787               C  ...           -53.88333             -36.02000
# 14788               C  ...           -53.88333             -36.02000
#
#        latitude_fsr  longitude_fsr  latitude longitude notes  \
# 0               NaN            NaN -61.70000 -57.00000   NaN
# 1               NaN            NaN -61.67000 -57.12000   NaN
# 2               NaN            NaN -61.75000 -58.15000   NaN
# 3               NaN            NaN -61.63000 -57.97000   NaN
# 4               NaN            NaN -61.65000 -58.08000   NaN
# ...             ...            ...       ...       ...   ...
# 14784           NaN            NaN -53.85167 -35.99000   NaN
# 14785           NaN            NaN -53.87667 -36.03667   NaN
# 14786           NaN            NaN -53.87667 -36.03667   NaN
# 14787           NaN            NaN -53.86167 -35.99500   NaN
# 14788           NaN            NaN -53.86167 -35.99500   NaN
#
#       krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h
# 0                  3000.00               2.333333               3.000000
# 1                  2000.00               0.500000               1.166667
# 2                 15000.00               0.583333               1.666667
# 3                  5000.00               1.583333               2.533333
# 4                  4000.00                    NaN               2.666667
# ...                    ...                    ...                    ...
# 14784             29944.82               2.000000               2.000000
# 14785             16785.11               2.000000               2.000000
# 14786             16785.11               2.000000               2.000000
# 14787             33116.40               1.983333               1.983333
# 14788             33116.40               1.983333               1.983333
#
# [14226 rows x 37 columns]

# %%
crossing_long_s
# Out:
#         c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 0       30767          NaN             NaN              NaN         25.0
# 1       30768          NaN             NaN              NaN         26.0
# 2       30792          NaN             NaN              NaN         50.0
# 3       30894          NaN             NaN              NaN        152.0
# 4       30896          NaN             NaN              NaN        154.0
# ...       ...          ...             ...              ...          ...
# 14784  537053          NaN             NaN              NaN       4657.0
# 14785  537060          NaN             NaN              NaN       4664.0
# 14786  537061          NaN             NaN              NaN       4665.0
# 14787  537062          NaN             NaN              NaN       4666.0
# 14788  537063          NaN             NaN              NaN       4667.0
#
#       fishing_purpose_code  season_ccamlr target_species asd_code  \
# 0                        C           1999            KRI      481
# 1                        C           1999            KRI      481
# 2                        C           1999            KRI      481
# 3                        C           1999            KRI      481
# 4                        C           1999            KRI      481
# ...                    ...            ...            ...      ...
# 14784                    C           2023            KRI      483
# 14785                    C           2023            KRI      483
# 14786                    C           2023            KRI      483
# 14787                    C           2023            KRI      483
# 14788                    C           2023            KRI      483
#
#       trawl_technique  ... latitude_haul_start  longitude_haul_start  \
# 0                   T  ...           -61.68000             -56.97000
# 1                   T  ...           -61.67000             -56.97000
# 2                   T  ...           -61.75000             -57.98000
# 3                   T  ...           -61.65000             -58.03000
# 4                   T  ...           -61.65000             -57.98000
# ...               ...  ...                 ...                   ...
# 14784               C  ...           -53.88000             -36.02333
# 14785               C  ...           -53.86167             -35.99500
# 14786               C  ...           -53.86167             -35.99500
# 14787               C  ...           -53.88333             -36.02000
# 14788               C  ...           -53.88333             -36.02000
#
#        latitude  longitude  notes krill_greenweight_kg trawl_duration_depth_h  \
# 0     -61.70000  -57.00000    NaN              3000.00               2.333333
# 1     -61.67000  -57.12000    NaN              2000.00               0.500000
# 2     -61.75000  -58.15000    NaN             15000.00               0.583333
# 3     -61.63000  -57.97000    NaN              5000.00               1.583333
# 4     -61.65000  -58.08000    NaN              4000.00                    NaN
# ...         ...        ...    ...                  ...                    ...
# 14784 -53.85167  -35.99000    NaN             29944.82               2.000000
# 14785 -53.87667  -36.03667    NaN             16785.11               2.000000
# 14786 -53.87667  -36.03667    NaN             16785.11               2.000000
# 14787 -53.86167  -35.99500    NaN             33116.40               1.983333
# 14788 -53.86167  -35.99500    NaN             33116.40               1.983333
#
#       trawl_duration_total_h longitude_fsr latitude_fsr
# 0                   3.000000         -56.5       -61.75
# 1                   1.166667         -56.5       -61.75
# 2                   1.666667         -57.5       -61.75
# 3                   2.533333         -58.5       -61.75
# 4                   2.666667         -57.5       -61.75
# ...                      ...           ...          ...
# 14784               2.000000         -36.5       -53.75
# 14785               2.000000         -35.5       -53.75
# 14786               2.000000         -35.5       -53.75
# 14787               1.983333         -36.5       -53.75
# 14788               1.983333         -36.5       -53.75
#
# [14226 rows x 37 columns]

# %%
crossing_long_e
# Out:
#         c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 0       30767          NaN             NaN              NaN         25.0
# 1       30768          NaN             NaN              NaN         26.0
# 2       30792          NaN             NaN              NaN         50.0
# 3       30894          NaN             NaN              NaN        152.0
# 4       30896          NaN             NaN              NaN        154.0
# ...       ...          ...             ...              ...          ...
# 14784  537053          NaN             NaN              NaN       4657.0
# 14785  537060          NaN             NaN              NaN       4664.0
# 14786  537061          NaN             NaN              NaN       4665.0
# 14787  537062          NaN             NaN              NaN       4666.0
# 14788  537063          NaN             NaN              NaN       4667.0
#
#       fishing_purpose_code  season_ccamlr target_species asd_code  \
# 0                        C           1999            KRI      481
# 1                        C           1999            KRI      481
# 2                        C           1999            KRI      481
# 3                        C           1999            KRI      481
# 4                        C           1999            KRI      481
# ...                    ...            ...            ...      ...
# 14784                    C           2023            KRI      483
# 14785                    C           2023            KRI      483
# 14786                    C           2023            KRI      483
# 14787                    C           2023            KRI      483
# 14788                    C           2023            KRI      483
#
#       trawl_technique  ... latitude_haul_start  longitude_haul_start  \
# 0                   T  ...           -61.68000             -56.97000
# 1                   T  ...           -61.67000             -56.97000
# 2                   T  ...           -61.75000             -57.98000
# 3                   T  ...           -61.65000             -58.03000
# 4                   T  ...           -61.65000             -57.98000
# ...               ...  ...                 ...                   ...
# 14784               C  ...           -53.88000             -36.02333
# 14785               C  ...           -53.86167             -35.99500
# 14786               C  ...           -53.86167             -35.99500
# 14787               C  ...           -53.88333             -36.02000
# 14788               C  ...           -53.88333             -36.02000
#
#        latitude  longitude  notes krill_greenweight_kg trawl_duration_depth_h  \
# 0     -61.70000  -57.00000    NaN              3000.00               2.333333
# 1     -61.67000  -57.12000    NaN              2000.00               0.500000
# 2     -61.75000  -58.15000    NaN             15000.00               0.583333
# 3     -61.63000  -57.97000    NaN              5000.00               1.583333
# 4     -61.65000  -58.08000    NaN              4000.00                    NaN
# ...         ...        ...    ...                  ...                    ...
# 14784 -53.85167  -35.99000    NaN             29944.82               2.000000
# 14785 -53.87667  -36.03667    NaN             16785.11               2.000000
# 14786 -53.87667  -36.03667    NaN             16785.11               2.000000
# 14787 -53.86167  -35.99500    NaN             33116.40               1.983333
# 14788 -53.86167  -35.99500    NaN             33116.40               1.983333
#
#       trawl_duration_total_h longitude_fsr latitude_fsr
# 0                   3.000000         -57.5       -61.75
# 1                   1.166667         -57.5       -61.75
# 2                   1.666667         -58.5       -61.75
# 3                   2.533333         -57.5       -61.75
# 4                   2.666667         -58.5       -61.75
# ...                      ...           ...          ...
# 14784               2.000000         -35.5       -53.75
# 14785               2.000000         -36.5       -53.75
# 14786               2.000000         -36.5       -53.75
# 14787               1.983333         -35.5       -53.75
# 14788               1.983333         -35.5       -53.75
#
# [14226 rows x 37 columns]

# %%
#check : no tows crossing more than two cells
max(np.trunc(crossing_long_e['longitude_haul_start']) - np.trunc(crossing_long_e['longitude'])) #OK
# Out:
# 1.0

# %% [markdown]
# ### Calculate the proportion the tow on each cell
#
# For a tow crossing two cells named $i$ (start) and $y$ (end):
#
# The proportion $p_i$, the proportion of the tow in the cell $i$ is defined as :
# $$ p_i = \frac{|lat_{start} - x|}{|lat_{end} - lat_{start}|} $$
#
# Where $x$ is the coordinate (here latitude) of the cell border (between $i$ and $y$). We can have $x$ by calculating the median or mean between the midpoint of the to cells.
#
# Then, for a biomass catched in a tow $B$, $B_i$ the biomass attributed to the cell $i$ is
# $$ B_i = p_i \times B$$
#
# We have respectively the same for the cell $y$:
# $$ p_y = \frac{|lat_{end} - x|}{|lat_{end} - lat_{start}|} $$
#
# $$ B_y = p_y \times B$$

# %%
# function to assign the biomass to each cell
def prop_biomass(start, end, biomass, dim, start_end):
    if dim == 'lat':
        x = (round_latitude(start) + round_latitude(end))/2
        if start_end == 'start': 
            prop = (np.abs(start - x))/(np.abs(start - end))
            b = biomass * prop
        if start_end == 'end':
            prop = (np.abs(end - x))/(np.abs(start - end))
            b = biomass * prop
        return([b, prop])
    
    if dim == 'long':
        x = (start.apply(round_longitude) + end.apply(round_longitude))/2
        if start_end == 'start':
            prop = (np.abs(start - x))/(np.abs(start - end))
            b = biomass * prop
        if start_end == 'end':
            prop = (np.abs(end - x))/(np.abs(start - end))
            b = biomass * prop
        return([b, prop])

# %%
# apply to latitude
crossing_lat_s['krill_greenweight_kg'] = prop_biomass(start = crossing_lat_s['latitude_haul_start'], end = crossing_lat_s['latitude'], biomass = crossing_lat_only['krill_greenweight_kg'], dim = 'lat', start_end = 'start')[0]
crossing_lat_s['proportion'] = prop_biomass(start = crossing_lat_s['latitude_haul_start'], end = crossing_lat_s['latitude'], biomass = crossing_lat_only['krill_greenweight_kg'], dim = 'lat', start_end = 'start')[1]

crossing_lat_e['krill_greenweight_kg']= prop_biomass(start = crossing_lat_e['latitude_haul_start'], end = crossing_lat_e['latitude'], biomass = crossing_lat_only['krill_greenweight_kg'], dim = 'lat', start_end = 'end')[0]
crossing_lat_e['proportion']= prop_biomass(start = crossing_lat_e['latitude_haul_start'], end = crossing_lat_e['latitude'], biomass = crossing_lat_only['krill_greenweight_kg'], dim = 'lat', start_end = 'end')[1]

# %%
crossing_lat_e
# Out:
#         c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 0       30777          NaN             NaN              NaN         35.0
# 1       31336          NaN             NaN              NaN        158.0
# 2       31355          NaN             NaN              NaN        177.0
# 3       31379          NaN             NaN              NaN        201.0
# 4       31380          NaN             NaN              NaN        202.0
# ...       ...          ...             ...              ...          ...
# 12898  534660     347043.0          2413.0           1768.0       1768.0
# 12899  534661     347044.0          2413.0           1769.0       1769.0
# 12900  534664     347047.0          2413.0           1772.0       1772.0
# 12901  536334          NaN             NaN              NaN       3790.0
# 12902  536335          NaN             NaN              NaN       3791.0
#
#       fishing_purpose_code  season_ccamlr target_species asd_code  \
# 0                        C           1999            KRI      481
# 1                        C           1999            KRI      482
# 2                        C           1999            KRI      482
# 3                        C           1999            KRI      482
# 4                        C           1999            KRI      482
# ...                    ...            ...            ...      ...
# 12898                    C           2023            KRI      483
# 12899                    C           2023            KRI      483
# 12900                    C           2023            KRI      483
# 12901                    C           2023            KRI      483
# 12902                    C           2023            KRI      483
#
#       trawl_technique  ... longitude_haul_start  latitude  longitude  notes  \
# 0                   T  ...            -57.23000 -61.93000  -57.22000    NaN
# 1                   T  ...            -46.32000 -60.48000  -46.27000    NaN
# 2                   T  ...            -46.37000 -60.50000  -46.37000    NaN
# 3                   T  ...            -46.48000 -60.45000  -46.40000    NaN
# 4                   T  ...            -46.50000 -60.58000  -46.50000    NaN
# ...               ...  ...                  ...       ...        ...    ...
# 12898               T  ...            -35.61883 -53.99283  -35.64667    NaN
# 12899               T  ...            -35.64083 -54.00617  -35.61700    NaN
# 12900               T  ...            -35.61883 -53.99417  -35.62700    NaN
# 12901               C  ...            -36.53167 -53.49667  -36.45667    NaN
# 12902               C  ...            -36.53167 -53.49667  -36.45667    NaN
#
#        krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h  \
# 0               2000.000000               1.083333               2.016667
# 1               7500.000000               1.000000               1.583333
# 2                  0.000000               0.916667               1.416667
# 3              10000.000000               0.916667               1.583333
# 4               2400.000000               1.083333               1.666667
# ...                     ...                    ...                    ...
# 12898          13170.827833               0.500000               0.916667
# 12899           8870.576093               0.500000               1.000000
# 12900          18877.837628               0.250000               0.666667
# 12901              0.750693               2.000000               2.000000
# 12902              0.750693               2.000000               2.000000
#
#       longitude_fsr latitude_fsr proportion
# 0             -57.5       -61.75   1.000000
# 1             -46.5       -60.25   0.500000
# 2             -46.5       -60.75   0.000000
# 3             -46.5       -60.25   1.000000
# 4             -46.5       -60.75   0.400000
# ...             ...          ...        ...
# 12898         -35.5       -53.75   0.641898
# 12899         -35.5       -54.25   0.411333
# 12900         -35.5       -53.75   0.875375
# 12901         -36.5       -53.25   0.153740
# 12902         -36.5       -53.25   0.153740
#
# [12340 rows x 38 columns]

# %%
crossing_lat_s
# Out:
#         c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 0       30777          NaN             NaN              NaN         35.0
# 1       31336          NaN             NaN              NaN        158.0
# 2       31355          NaN             NaN              NaN        177.0
# 3       31379          NaN             NaN              NaN        201.0
# 4       31380          NaN             NaN              NaN        202.0
# ...       ...          ...             ...              ...          ...
# 12898  534660     347043.0          2413.0           1768.0       1768.0
# 12899  534661     347044.0          2413.0           1769.0       1769.0
# 12900  534664     347047.0          2413.0           1772.0       1772.0
# 12901  536334          NaN             NaN              NaN       3790.0
# 12902  536335          NaN             NaN              NaN       3791.0
#
#       fishing_purpose_code  season_ccamlr target_species asd_code  \
# 0                        C           1999            KRI      481
# 1                        C           1999            KRI      482
# 2                        C           1999            KRI      482
# 3                        C           1999            KRI      482
# 4                        C           1999            KRI      482
# ...                    ...            ...            ...      ...
# 12898                    C           2023            KRI      483
# 12899                    C           2023            KRI      483
# 12900                    C           2023            KRI      483
# 12901                    C           2023            KRI      483
# 12902                    C           2023            KRI      483
#
#       trawl_technique  ... longitude_haul_start  latitude  longitude  notes  \
# 0                   T  ...            -57.23000 -61.93000  -57.22000    NaN
# 1                   T  ...            -46.32000 -60.48000  -46.27000    NaN
# 2                   T  ...            -46.37000 -60.50000  -46.37000    NaN
# 3                   T  ...            -46.48000 -60.45000  -46.40000    NaN
# 4                   T  ...            -46.50000 -60.58000  -46.50000    NaN
# ...               ...  ...                  ...       ...        ...    ...
# 12898               T  ...            -35.61883 -53.99283  -35.64667    NaN
# 12899               T  ...            -35.64083 -54.00617  -35.61700    NaN
# 12900               T  ...            -35.61883 -53.99417  -35.62700    NaN
# 12901               C  ...            -36.53167 -53.49667  -36.45667    NaN
# 12902               C  ...            -36.53167 -53.49667  -36.45667    NaN
#
#        krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h  \
# 0                  0.000000               1.083333               2.016667
# 1               7500.000000               1.000000               1.583333
# 2               8000.000000               0.916667               1.416667
# 3                  0.000000               0.916667               1.583333
# 4               3600.000000               1.083333               1.666667
# ...                     ...                    ...                    ...
# 12898           7347.742167               0.500000               0.916667
# 12899          12694.843907               0.500000               1.000000
# 12900           2687.582372               0.250000               0.666667
# 12901              4.132195               2.000000               2.000000
# 12902              4.132195               2.000000               2.000000
#
#       longitude_fsr latitude_fsr proportion
# 0             -57.5       -62.25   0.000000
# 1             -46.5       -60.75   0.500000
# 2             -46.5       -60.25   1.000000
# 3             -46.5       -60.75   0.000000
# 4             -46.5       -60.25   0.600000
# ...             ...          ...        ...
# 12898         -35.5       -54.25   0.358102
# 12899         -35.5       -53.75   0.588667
# 12900         -35.5       -54.25   0.124625
# 12901         -36.5       -53.75   0.846260
# 12902         -36.5       -53.75   0.846260
#
# [12340 rows x 38 columns]

# %%
## concatenate start and end datasets
crossing_lat_adjusted = pd.concat([crossing_lat_s, crossing_lat_e])
crossing_lat_adjusted   # 24680 rows × 38
# Out:
#         c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 0       30777          NaN             NaN              NaN         35.0
# 1       31336          NaN             NaN              NaN        158.0
# 2       31355          NaN             NaN              NaN        177.0
# 3       31379          NaN             NaN              NaN        201.0
# 4       31380          NaN             NaN              NaN        202.0
# ...       ...          ...             ...              ...          ...
# 12898  534660     347043.0          2413.0           1768.0       1768.0
# 12899  534661     347044.0          2413.0           1769.0       1769.0
# 12900  534664     347047.0          2413.0           1772.0       1772.0
# 12901  536334          NaN             NaN              NaN       3790.0
# 12902  536335          NaN             NaN              NaN       3791.0
#
#       fishing_purpose_code  season_ccamlr target_species asd_code  \
# 0                        C           1999            KRI      481
# 1                        C           1999            KRI      482
# 2                        C           1999            KRI      482
# 3                        C           1999            KRI      482
# 4                        C           1999            KRI      482
# ...                    ...            ...            ...      ...
# 12898                    C           2023            KRI      483
# 12899                    C           2023            KRI      483
# 12900                    C           2023            KRI      483
# 12901                    C           2023            KRI      483
# 12902                    C           2023            KRI      483
#
#       trawl_technique  ... longitude_haul_start  latitude  longitude  notes  \
# 0                   T  ...            -57.23000 -61.93000  -57.22000    NaN
# 1                   T  ...            -46.32000 -60.48000  -46.27000    NaN
# 2                   T  ...            -46.37000 -60.50000  -46.37000    NaN
# 3                   T  ...            -46.48000 -60.45000  -46.40000    NaN
# 4                   T  ...            -46.50000 -60.58000  -46.50000    NaN
# ...               ...  ...                  ...       ...        ...    ...
# 12898               T  ...            -35.61883 -53.99283  -35.64667    NaN
# 12899               T  ...            -35.64083 -54.00617  -35.61700    NaN
# 12900               T  ...            -35.61883 -53.99417  -35.62700    NaN
# 12901               C  ...            -36.53167 -53.49667  -36.45667    NaN
# 12902               C  ...            -36.53167 -53.49667  -36.45667    NaN
#
#        krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h  \
# 0                  0.000000               1.083333               2.016667
# 1               7500.000000               1.000000               1.583333
# 2               8000.000000               0.916667               1.416667
# 3                  0.000000               0.916667               1.583333
# 4               3600.000000               1.083333               1.666667
# ...                     ...                    ...                    ...
# 12898          13170.827833               0.500000               0.916667
# 12899           8870.576093               0.500000               1.000000
# 12900          18877.837628               0.250000               0.666667
# 12901              0.750693               2.000000               2.000000
# 12902              0.750693               2.000000               2.000000
#
#       longitude_fsr latitude_fsr proportion
# 0             -57.5       -62.25   0.000000
# 1             -46.5       -60.75   0.500000
# 2             -46.5       -60.25   1.000000
# 3             -46.5       -60.75   0.000000
# 4             -46.5       -60.25   0.600000
# ...             ...          ...        ...
# 12898         -35.5       -53.75   0.641898
# 12899         -35.5       -54.25   0.411333
# 12900         -35.5       -53.75   0.875375
# 12901         -36.5       -53.25   0.153740
# 12902         -36.5       -53.25   0.153740
#
# [24680 rows x 38 columns]

# %%
# apply to longitude 
crossing_long_s['krill_greenweight_kg'] = prop_biomass(start = crossing_long_s['longitude_haul_start'], end = crossing_long_s['longitude'], biomass = crossing_long_only['krill_greenweight_kg'], dim = 'long', start_end = 'start')[0]
crossing_long_s['proportion'] = prop_biomass(start = crossing_long_s['longitude_haul_start'], end = crossing_long_s['longitude'], biomass = crossing_long_only['krill_greenweight_kg'], dim = 'long', start_end = 'start')[1]

crossing_long_e['krill_greenweight_kg']= prop_biomass(start = crossing_long_e['longitude_haul_start'], end = crossing_long_e['longitude'], biomass = crossing_long_only['krill_greenweight_kg'], dim = 'long', start_end = 'end')[0]
crossing_long_e['proportion']= prop_biomass(start = crossing_long_e['longitude_haul_start'], end = crossing_long_e['longitude'], biomass = crossing_long_only['krill_greenweight_kg'], dim = 'long', start_end = 'end')[1]

# %%
crossing_long_s
# Out:
#         c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 0       30767          NaN             NaN              NaN         25.0
# 1       30768          NaN             NaN              NaN         26.0
# 2       30792          NaN             NaN              NaN         50.0
# 3       30894          NaN             NaN              NaN        152.0
# 4       30896          NaN             NaN              NaN        154.0
# ...       ...          ...             ...              ...          ...
# 14784  537053          NaN             NaN              NaN       4657.0
# 14785  537060          NaN             NaN              NaN       4664.0
# 14786  537061          NaN             NaN              NaN       4665.0
# 14787  537062          NaN             NaN              NaN       4666.0
# 14788  537063          NaN             NaN              NaN       4667.0
#
#       fishing_purpose_code  season_ccamlr target_species asd_code  \
# 0                        C           1999            KRI      481
# 1                        C           1999            KRI      481
# 2                        C           1999            KRI      481
# 3                        C           1999            KRI      481
# 4                        C           1999            KRI      481
# ...                    ...            ...            ...      ...
# 14784                    C           2023            KRI      483
# 14785                    C           2023            KRI      483
# 14786                    C           2023            KRI      483
# 14787                    C           2023            KRI      483
# 14788                    C           2023            KRI      483
#
#       trawl_technique  ... longitude_haul_start  latitude  longitude  notes  \
# 0                   T  ...            -56.97000 -61.70000  -57.00000    NaN
# 1                   T  ...            -56.97000 -61.67000  -57.12000    NaN
# 2                   T  ...            -57.98000 -61.75000  -58.15000    NaN
# 3                   T  ...            -58.03000 -61.63000  -57.97000    NaN
# 4                   T  ...            -57.98000 -61.65000  -58.08000    NaN
# ...               ...  ...                  ...       ...        ...    ...
# 14784               C  ...            -36.02333 -53.85167  -35.99000    NaN
# 14785               C  ...            -35.99500 -53.87667  -36.03667    NaN
# 14786               C  ...            -35.99500 -53.87667  -36.03667    NaN
# 14787               C  ...            -36.02000 -53.86167  -35.99500    NaN
# 14788               C  ...            -36.02000 -53.86167  -35.99500    NaN
#
#        krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h  \
# 0               3000.000000               2.333333               3.000000
# 1                400.000000               0.500000               1.166667
# 2               1764.705882               0.583333               1.666667
# 3               2500.000000               1.583333               2.533333
# 4                800.000000                    NaN               2.666667
# ...                     ...                    ...                    ...
# 14784          20960.475566               2.000000               2.000000
# 14785           2014.052076               2.000000               2.000000
# 14786           2014.052076               2.000000               2.000000
# 14787          26493.120000               1.983333               1.983333
# 14788          26493.120000               1.983333               1.983333
#
#       longitude_fsr latitude_fsr proportion
# 0             -56.5       -61.75   1.000000
# 1             -56.5       -61.75   0.200000
# 2             -57.5       -61.75   0.117647
# 3             -58.5       -61.75   0.500000
# 4             -57.5       -61.75   0.200000
# ...             ...          ...        ...
# 14784         -36.5       -53.75   0.699970
# 14785         -35.5       -53.75   0.119990
# 14786         -35.5       -53.75   0.119990
# 14787         -36.5       -53.75   0.800000
# 14788         -36.5       -53.75   0.800000
#
# [14226 rows x 38 columns]

# %%
crossing_long_e
# Out:
#         c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 0       30767          NaN             NaN              NaN         25.0
# 1       30768          NaN             NaN              NaN         26.0
# 2       30792          NaN             NaN              NaN         50.0
# 3       30894          NaN             NaN              NaN        152.0
# 4       30896          NaN             NaN              NaN        154.0
# ...       ...          ...             ...              ...          ...
# 14784  537053          NaN             NaN              NaN       4657.0
# 14785  537060          NaN             NaN              NaN       4664.0
# 14786  537061          NaN             NaN              NaN       4665.0
# 14787  537062          NaN             NaN              NaN       4666.0
# 14788  537063          NaN             NaN              NaN       4667.0
#
#       fishing_purpose_code  season_ccamlr target_species asd_code  \
# 0                        C           1999            KRI      481
# 1                        C           1999            KRI      481
# 2                        C           1999            KRI      481
# 3                        C           1999            KRI      481
# 4                        C           1999            KRI      481
# ...                    ...            ...            ...      ...
# 14784                    C           2023            KRI      483
# 14785                    C           2023            KRI      483
# 14786                    C           2023            KRI      483
# 14787                    C           2023            KRI      483
# 14788                    C           2023            KRI      483
#
#       trawl_technique  ... longitude_haul_start  latitude  longitude  notes  \
# 0                   T  ...            -56.97000 -61.70000  -57.00000    NaN
# 1                   T  ...            -56.97000 -61.67000  -57.12000    NaN
# 2                   T  ...            -57.98000 -61.75000  -58.15000    NaN
# 3                   T  ...            -58.03000 -61.63000  -57.97000    NaN
# 4                   T  ...            -57.98000 -61.65000  -58.08000    NaN
# ...               ...  ...                  ...       ...        ...    ...
# 14784               C  ...            -36.02333 -53.85167  -35.99000    NaN
# 14785               C  ...            -35.99500 -53.87667  -36.03667    NaN
# 14786               C  ...            -35.99500 -53.87667  -36.03667    NaN
# 14787               C  ...            -36.02000 -53.86167  -35.99500    NaN
# 14788               C  ...            -36.02000 -53.86167  -35.99500    NaN
#
#        krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h  \
# 0                  0.000000               2.333333               3.000000
# 1               1600.000000               0.500000               1.166667
# 2              13235.294118               0.583333               1.666667
# 3               2500.000000               1.583333               2.533333
# 4               3200.000000                    NaN               2.666667
# ...                     ...                    ...                    ...
# 14784           8984.344434               2.000000               2.000000
# 14785          14771.057924               2.000000               2.000000
# 14786          14771.057924               2.000000               2.000000
# 14787           6623.280000               1.983333               1.983333
# 14788           6623.280000               1.983333               1.983333
#
#       longitude_fsr latitude_fsr proportion
# 0             -57.5       -61.75   0.000000
# 1             -57.5       -61.75   0.800000
# 2             -58.5       -61.75   0.882353
# 3             -57.5       -61.75   0.500000
# 4             -58.5       -61.75   0.800000
# ...             ...          ...        ...
# 14784         -35.5       -53.75   0.300030
# 14785         -36.5       -53.75   0.880010
# 14786         -36.5       -53.75   0.880010
# 14787         -35.5       -53.75   0.200000
# 14788         -35.5       -53.75   0.200000
#
# [14226 rows x 38 columns]

# %%
## concatenate start and end datasets
crossing_long_adjusted = pd.concat([crossing_long_s, crossing_long_e])
crossing_long_adjusted   # 28452  rows × 38
# Out:
#         c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 0       30767          NaN             NaN              NaN         25.0
# 1       30768          NaN             NaN              NaN         26.0
# 2       30792          NaN             NaN              NaN         50.0
# 3       30894          NaN             NaN              NaN        152.0
# 4       30896          NaN             NaN              NaN        154.0
# ...       ...          ...             ...              ...          ...
# 14784  537053          NaN             NaN              NaN       4657.0
# 14785  537060          NaN             NaN              NaN       4664.0
# 14786  537061          NaN             NaN              NaN       4665.0
# 14787  537062          NaN             NaN              NaN       4666.0
# 14788  537063          NaN             NaN              NaN       4667.0
#
#       fishing_purpose_code  season_ccamlr target_species asd_code  \
# 0                        C           1999            KRI      481
# 1                        C           1999            KRI      481
# 2                        C           1999            KRI      481
# 3                        C           1999            KRI      481
# 4                        C           1999            KRI      481
# ...                    ...            ...            ...      ...
# 14784                    C           2023            KRI      483
# 14785                    C           2023            KRI      483
# 14786                    C           2023            KRI      483
# 14787                    C           2023            KRI      483
# 14788                    C           2023            KRI      483
#
#       trawl_technique  ... longitude_haul_start  latitude  longitude  notes  \
# 0                   T  ...            -56.97000 -61.70000  -57.00000    NaN
# 1                   T  ...            -56.97000 -61.67000  -57.12000    NaN
# 2                   T  ...            -57.98000 -61.75000  -58.15000    NaN
# 3                   T  ...            -58.03000 -61.63000  -57.97000    NaN
# 4                   T  ...            -57.98000 -61.65000  -58.08000    NaN
# ...               ...  ...                  ...       ...        ...    ...
# 14784               C  ...            -36.02333 -53.85167  -35.99000    NaN
# 14785               C  ...            -35.99500 -53.87667  -36.03667    NaN
# 14786               C  ...            -35.99500 -53.87667  -36.03667    NaN
# 14787               C  ...            -36.02000 -53.86167  -35.99500    NaN
# 14788               C  ...            -36.02000 -53.86167  -35.99500    NaN
#
#        krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h  \
# 0               3000.000000               2.333333               3.000000
# 1                400.000000               0.500000               1.166667
# 2               1764.705882               0.583333               1.666667
# 3               2500.000000               1.583333               2.533333
# 4                800.000000                    NaN               2.666667
# ...                     ...                    ...                    ...
# 14784           8984.344434               2.000000               2.000000
# 14785          14771.057924               2.000000               2.000000
# 14786          14771.057924               2.000000               2.000000
# 14787           6623.280000               1.983333               1.983333
# 14788           6623.280000               1.983333               1.983333
#
#       longitude_fsr latitude_fsr proportion
# 0             -56.5       -61.75   1.000000
# 1             -56.5       -61.75   0.200000
# 2             -57.5       -61.75   0.117647
# 3             -58.5       -61.75   0.500000
# 4             -57.5       -61.75   0.200000
# ...             ...          ...        ...
# 14784         -35.5       -53.75   0.300030
# 14785         -36.5       -53.75   0.880010
# 14786         -36.5       -53.75   0.880010
# 14787         -35.5       -53.75   0.200000
# 14788         -35.5       -53.75   0.200000
#
# [28452 rows x 38 columns]

# %%
# concatenate lat and long datasets together
crossing_lat_long_adjusted = pd.concat([crossing_lat_adjusted, crossing_long_adjusted])
crossing_lat_long_adjusted # 53132 rows × 38 (= 28452 +24680)
# Out:
#         c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 0       30777          NaN             NaN              NaN         35.0
# 1       31336          NaN             NaN              NaN        158.0
# 2       31355          NaN             NaN              NaN        177.0
# 3       31379          NaN             NaN              NaN        201.0
# 4       31380          NaN             NaN              NaN        202.0
# ...       ...          ...             ...              ...          ...
# 14784  537053          NaN             NaN              NaN       4657.0
# 14785  537060          NaN             NaN              NaN       4664.0
# 14786  537061          NaN             NaN              NaN       4665.0
# 14787  537062          NaN             NaN              NaN       4666.0
# 14788  537063          NaN             NaN              NaN       4667.0
#
#       fishing_purpose_code  season_ccamlr target_species asd_code  \
# 0                        C           1999            KRI      481
# 1                        C           1999            KRI      482
# 2                        C           1999            KRI      482
# 3                        C           1999            KRI      482
# 4                        C           1999            KRI      482
# ...                    ...            ...            ...      ...
# 14784                    C           2023            KRI      483
# 14785                    C           2023            KRI      483
# 14786                    C           2023            KRI      483
# 14787                    C           2023            KRI      483
# 14788                    C           2023            KRI      483
#
#       trawl_technique  ... longitude_haul_start  latitude  longitude  notes  \
# 0                   T  ...            -57.23000 -61.93000  -57.22000    NaN
# 1                   T  ...            -46.32000 -60.48000  -46.27000    NaN
# 2                   T  ...            -46.37000 -60.50000  -46.37000    NaN
# 3                   T  ...            -46.48000 -60.45000  -46.40000    NaN
# 4                   T  ...            -46.50000 -60.58000  -46.50000    NaN
# ...               ...  ...                  ...       ...        ...    ...
# 14784               C  ...            -36.02333 -53.85167  -35.99000    NaN
# 14785               C  ...            -35.99500 -53.87667  -36.03667    NaN
# 14786               C  ...            -35.99500 -53.87667  -36.03667    NaN
# 14787               C  ...            -36.02000 -53.86167  -35.99500    NaN
# 14788               C  ...            -36.02000 -53.86167  -35.99500    NaN
#
#        krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h  \
# 0                  0.000000               1.083333               2.016667
# 1               7500.000000               1.000000               1.583333
# 2               8000.000000               0.916667               1.416667
# 3                  0.000000               0.916667               1.583333
# 4               3600.000000               1.083333               1.666667
# ...                     ...                    ...                    ...
# 14784           8984.344434               2.000000               2.000000
# 14785          14771.057924               2.000000               2.000000
# 14786          14771.057924               2.000000               2.000000
# 14787           6623.280000               1.983333               1.983333
# 14788           6623.280000               1.983333               1.983333
#
#       longitude_fsr latitude_fsr proportion
# 0             -57.5       -62.25    0.00000
# 1             -46.5       -60.75    0.50000
# 2             -46.5       -60.25    1.00000
# 3             -46.5       -60.75    0.00000
# 4             -46.5       -60.25    0.60000
# ...             ...          ...        ...
# 14784         -35.5       -53.75    0.30003
# 14785         -36.5       -53.75    0.88001
# 14786         -36.5       -53.75    0.88001
# 14787         -35.5       -53.75    0.20000
# 14788         -35.5       -53.75    0.20000
#
# [53132 rows x 38 columns]

# %% [markdown]
# ### In the case of tows on 3 cells (when both lat and long borders are crossed by a tow)
#
# We have to calculate the proportion of the tow on each of the crossed cells.
#
# We slip the segment (the tow) in N pieces :
# for $x_1$ and $x_2$ the longitude of the start and the end respectively, and $y_1$, $y_2$ the latitude of the start and the end respectively, the coordinates of the points alpong the tow segmant are
#
# $$ x_i = x_1 + \frac{(x_2 - x_1)}{N} \times i $$ with $N= 100$
#
# and for longitude:
# $$ y_i = \frac{y_1 - y_2}{x_1 - x_2} \times (x_i-x_1) + y_1$$
#
# The we use the 'round' function to round each $x_i$, $y_i$ to the nearest cell center.
# Then we can calculate the proportion of $(x_i, y_i)$ point that fall within each cell. The corresponding biomass is then assigned to each cell.

# %%
crossing_both
# Out:
#       c1_id  obs_haul_id  obs_logbook_id  obs_haul_number  haul_number  \
# 0     33581          NaN             NaN              NaN        240.0
# 1     39813      12577.0            38.0            116.0        116.0
# 2     40649          NaN             NaN              NaN         12.0
# 3     40653          NaN             NaN              NaN         16.0
# 4     40654          NaN             NaN              NaN         17.0
# ..      ...          ...             ...              ...          ...
# 558  520229     328888.0          2341.0            255.0        255.0
# 559  521014     348021.0          2424.0            516.0        516.0
# 560  531216     348194.0          2424.0           1129.0       1129.0
# 561  531221     348199.0          2424.0           1134.0       1134.0
# 562  532559     347140.0          2417.0            122.0        122.0
#
#     fishing_purpose_code  season_ccamlr target_species asd_code  \
# 0                      C           1999            KRI      481
# 1                      C           2001            KRI      481
# 2                      C           2002            KRI      481
# 3                      C           2002            KRI      481
# 4                      C           2002            KRI      481
# ..                   ...            ...            ...      ...
# 558                    C           2023            KRI      482
# 559                    C           2023            KRI      482
# 560                    C           2023            KRI      481
# 561                    C           2023            KRI      481
# 562                    C           2023            KRI      481
#
#     trawl_technique  ... latitude_haul_start  longitude_haul_start  \
# 0                 T  ...          -61.000000            -54.933333
# 1                 T  ...          -62.885000            -59.945000
# 2                 T  ...          -62.875000            -59.171667
# 3                 T  ...          -62.916667            -59.233333
# 4                 T  ...          -62.940000            -59.036667
# ..              ...  ...                 ...                   ...
# 558               T  ...          -60.498330            -45.110000
# 559               T  ...          -60.540000            -44.940000
# 560               T  ...          -61.998330            -54.995000
# 561               T  ...          -61.995000            -54.000000
# 562               T  ...          -62.965000            -58.003330
#
#      latitude_fsr  longitude_fsr   latitude  longitude notes  \
# 0             NaN            NaN -60.966667 -55.050000   NaN
# 1             NaN            NaN -63.011667 -60.023333   NaN
# 2             NaN            NaN -63.103333 -58.983333   NaN
# 3             NaN            NaN -63.078333 -58.971667   NaN
# 4             NaN            NaN -63.023333 -58.981667   NaN
# ..            ...            ...        ...        ...   ...
# 558           NaN            NaN -60.520000 -44.995000   NaN
# 559           NaN            NaN -60.496670 -45.050000   NaN
# 560           NaN            NaN -62.000000 -55.008330   NaN
# 561           NaN            NaN -62.000000 -53.998330   NaN
# 562           NaN            NaN -63.018330 -57.958330   NaN
#
#     krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h
# 0              2000.0000               1.333333               2.083333
# 1             15000.0000               2.750000               3.133333
# 2             35000.0000               4.750000               5.333333
# 3             35000.0000               2.833333               3.216667
# 4             15000.0000               1.750000               2.083333
# ..                   ...                    ...                    ...
# 558           46341.0000               4.983333               5.466667
# 559           10707.4000               2.416667               2.916667
# 560               0.0030               0.183333               0.683333
# 561               0.0001               0.250000               0.750000
# 562           16688.0000               5.033333               5.450000
#
# [563 rows x 37 columns]

# %%
# calculate the x_i and y_i 
def split_segment(long_start, lat_start, long_end, lat_end, N):
    arr_xi = np.array([])
    for i in np.arange(N+1):
        xi = long_start + (long_end-long_start)*i/N
        arr_xi = np.append(arr_xi, xi)

    arr_yi= ((lat_start - lat_end)/(long_start - long_end)) * (arr_xi - long_start) + lat_start
 
    res = pd.DataFrame({'x_i' : arr_xi, 'y_i' : arr_yi})
    
    res['longitude_fsr'] = res['x_i'].apply(round_longitude)
    res['latitude_fsr'] = res['y_i'].apply(round_latitude)
    res = res.groupby(['longitude_fsr', 'latitude_fsr']).count()
    res['proportion'] = res['x_i']/sum(res.x_i)
    return(res)

# %%
# apply the split_segment function to each line in crossing_both dataset
# a lot of Future Warning: 
#"Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead"
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)


crossing_both_adjusted = pd.DataFrame()
for index in np.arange(crossing_both.shape[0]):
    line = crossing_both.iloc[index].to_frame().transpose() # to keep it as a df, with the right shape
    adjusted_line = split_segment(long_start = float(line['longitude_haul_start']), 
                                  lat_start = float(line['latitude_haul_start']),
                                  long_end = float(line['longitude']),
                                  lat_end = float(line['latitude']), 
                                  N= 100)
    adjusted_line.reset_index(inplace=True)

    #create a 3 line dataset (duplicate line by the length of adjadjusted_line (should be 3))
    line_repeated = pd.concat([line]*adjusted_line.shape[0], ignore_index=True)
    
    # fill the columns with adjuadjusted_line info
    line_repeated['longitude_fsr'] = adjusted_line['longitude_fsr']
    line_repeated['latitude_fsr'] = adjusted_line['latitude_fsr']
    line_repeated['proportion'] = adjusted_line['proportion']
    line_repeated['krill_greenweight_kg'] = line_repeated['krill_greenweight_kg'] * line_repeated['proportion'] 

    crossing_both_adjusted = pd.concat([crossing_both_adjusted, line_repeated])

crossing_both_adjusted # 1654  rows × 38 (~3 times crossing_both)
# Out:
#      c1_id obs_haul_id obs_logbook_id obs_haul_number haul_number  \
# 0    33581         NaN            NaN             NaN       240.0
# 1    33581         NaN            NaN             NaN       240.0
# 2    33581         NaN            NaN             NaN       240.0
# 0    39813     12577.0           38.0           116.0       116.0
# 1    39813     12577.0           38.0           116.0       116.0
# ..     ...         ...            ...             ...         ...
# 1   531221    348199.0         2424.0          1134.0      1134.0
# 2   531221    348199.0         2424.0          1134.0      1134.0
# 0   532559    347140.0         2417.0           122.0       122.0
# 1   532559    347140.0         2417.0           122.0       122.0
# 2   532559    347140.0         2417.0           122.0       122.0
#
#    fishing_purpose_code season_ccamlr target_species asd_code trawl_technique  \
# 0                     C          1999            KRI      481               T
# 1                     C          1999            KRI      481               T
# 2                     C          1999            KRI      481               T
# 0                     C          2001            KRI      481               T
# 1                     C          2001            KRI      481               T
# ..                  ...           ...            ...      ...             ...
# 1                     C          2023            KRI      481               T
# 2                     C          2023            KRI      481               T
# 0                     C          2023            KRI      481               T
# 1                     C          2023            KRI      481               T
# 2                     C          2023            KRI      481               T
#
#     ... longitude_haul_start latitude_fsr longitude_fsr   latitude  longitude  \
# 0   ...           -54.933333       -60.75         -55.5 -60.966667     -55.05
# 1   ...           -54.933333       -61.25         -54.5 -60.966667     -55.05
# 2   ...           -54.933333       -60.75         -54.5 -60.966667     -55.05
# 0   ...              -59.945       -63.25         -60.5 -63.011667 -60.023333
# 1   ...              -59.945       -62.75         -60.5 -63.011667 -60.023333
# ..  ...                  ...          ...           ...        ...        ...
# 1   ...                -54.0       -62.25         -53.5      -62.0  -53.99833
# 2   ...                -54.0       -61.75         -53.5      -62.0  -53.99833
# 0   ...            -58.00333       -62.75         -58.5  -63.01833  -57.95833
# 1   ...            -58.00333       -63.25         -57.5  -63.01833  -57.95833
# 2   ...            -58.00333       -62.75         -57.5  -63.01833  -57.95833
#
#    notes krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h  \
# 0    NaN           851.485149               1.333333               2.083333
# 1    NaN             19.80198               1.333333               2.083333
# 2    NaN          1128.712871               1.333333               2.083333
# 0    NaN          1485.148515                   2.75               3.133333
# 1    NaN           2970.29703                   2.75               3.133333
# ..   ...                  ...                    ...                    ...
# 1    NaN             0.000001                   0.25                   0.75
# 2    NaN             0.000098                   0.25                   0.75
# 0    NaN          1321.821782               5.033333                   5.45
# 1    NaN          5782.970297               5.033333                   5.45
# 2    NaN          9583.207921               5.033333                   5.45
#
#    proportion
# 0    0.425743
# 1    0.009901
# 2    0.564356
# 0    0.099010
# 1    0.198020
# ..        ...
# 1    0.009901
# 2    0.980198
# 0    0.079208
# 1    0.346535
# 2    0.574257
#
# [1654 rows x 38 columns]

# %%
# Concatenate all the crossing data with the rest of the dataset (agg_data)
agg_data = pd.concat([agg_data, crossing_lat_long_adjusted, crossing_both_adjusted])
agg_data.shape # (431189, 38)
# Out:
# (431189, 38)

# %%
agg_data
# Out:
#      c1_id obs_haul_id obs_logbook_id obs_haul_number haul_number  \
# 0      344         NaN            NaN             NaN         NaN
# 1      345         NaN            NaN             NaN         NaN
# 2      346         NaN            NaN             NaN         NaN
# 3      347         NaN            NaN             NaN         NaN
# 4      348         NaN            NaN             NaN         NaN
# ..     ...         ...            ...             ...         ...
# 1   531221    348199.0         2424.0          1134.0      1134.0
# 2   531221    348199.0         2424.0          1134.0      1134.0
# 0   532559    347140.0         2417.0           122.0       122.0
# 1   532559    347140.0         2417.0           122.0       122.0
# 2   532559    347140.0         2417.0           122.0       122.0
#
#    fishing_purpose_code season_ccamlr target_species asd_code trawl_technique  \
# 0                     C          1988            KRI      481               T
# 1                     C          1988            KRI      482               T
# 2                     C          1988            KRI      482               T
# 3                     C          1988            KRI      482               T
# 4                     C          1988            KRI      482               T
# ..                  ...           ...            ...      ...             ...
# 1                     C          2023            KRI      481               T
# 2                     C          2023            KRI      481               T
# 0                     C          2023            KRI      481               T
# 1                     C          2023            KRI      481               T
# 2                     C          2023            KRI      481               T
#
#     ... longitude_haul_start latitude_fsr longitude_fsr  latitude longitude  \
# 0   ...                  NaN       -60.75         -55.5    -60.75     -55.5
# 1   ...                  NaN       -60.25         -46.5    -60.25     -46.5
# 2   ...                  NaN       -60.75         -46.5    -60.75     -46.5
# 3   ...                  NaN       -60.75         -47.5    -60.75     -47.5
# 4   ...                  NaN       -60.25         -46.5    -60.25     -46.5
# ..  ...                  ...          ...           ...       ...       ...
# 1   ...                -54.0       -62.25         -53.5     -62.0 -53.99833
# 2   ...                -54.0       -61.75         -53.5     -62.0 -53.99833
# 0   ...            -58.00333       -62.75         -58.5 -63.01833 -57.95833
# 1   ...            -58.00333       -63.25         -57.5 -63.01833 -57.95833
# 2   ...            -58.00333       -62.75         -57.5 -63.01833 -57.95833
#
#    notes krill_greenweight_kg trawl_duration_depth_h trawl_duration_total_h  \
# 0    NaN              55300.0                    NaN                    NaN
# 1    NaN              98100.0                    NaN                    NaN
# 2    NaN             300000.0                    NaN                    NaN
# 3    NaN              22800.0                    NaN                    NaN
# 4    NaN             304500.0                    NaN                    NaN
# ..   ...                  ...                    ...                    ...
# 1    NaN             0.000001                   0.25                   0.75
# 2    NaN             0.000098                   0.25                   0.75
# 0    NaN          1321.821782               5.033333                   5.45
# 1    NaN          5782.970297               5.033333                   5.45
# 2    NaN          9583.207921               5.033333                   5.45
#
#    proportion
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ..        ...
# 1    0.009901
# 2    0.980198
# 0    0.079208
# 1    0.346535
# 2    0.574257
#
# [431189 rows x 38 columns]

# %% [markdown]
# ## Combine (sum) the fishing records on the grid cells
#
# Now we properly aggregated all the fishing data on the 1°x0.5° long-lat grid. But we have several rows belonging to 1 cell (spatially and temporally, by year).
# So we have to sum all the record by cell coordinates and year (CCAMLR fishing season) in order to have 1 value of krill catch, for each cell, for each year (where available). When doing this, we will also retain the number of rows summed by cell to have an idea of the representativeness of the cell data, and this may also be an indicator of the fishing intensity.
#
# Then we convert the dataframe into an xarray format to visualize them. Then we can save the final dataset (as dataframe and xarray).

# %%
# First take a subset of the dataset with only the needed info for visualisation
agg_data_sub = agg_data[['longitude_fsr', 'latitude_fsr', 'krill_greenweight_kg', 'season_ccamlr']].set_index(['longitude_fsr', 'latitude_fsr', 'season_ccamlr'])

# group by lat and long (cell coordinates), and ccamlr_season, sum the krill_biomass, and count the record
agg_data_finescale = agg_data_sub.groupby(['longitude_fsr', 'latitude_fsr', 'season_ccamlr']).krill_greenweight_kg.agg(['sum', 'count'])

# rename the columns 
agg_data_finescale.rename(columns={"sum": "krill_greenweight_kg", "count" : "record_count"}, inplace = True)
agg_data_finescale # 2504 rows × 2 columns
# Out:
#                                          krill_greenweight_kg  record_count
# longitude_fsr latitude_fsr season_ccamlr
# -72.5         -64.75       1992                       41500.0             2
#               -64.25       1992                        8340.0             1
# -69.5         -65.25       1992                        4300.0             1
#                            1998                       29755.0             6
#               -64.75       1998                        1650.0             1
# ...                                                       ...           ...
#  148.5        -65.25       1990                        1960.0             2
#                            1994                         200.0             1
#               -64.75       1990                        1880.0             1
#  149.5        -64.75       1991                        3750.0             2
#  153.5        -64.25       1991                        2500.0             3
#
# [2504 rows x 2 columns]

# %%
def my_log(x):
    return np.log10(x+1)

agg_data_finescale['krill_greenweight_kg_log'] = agg_data_finescale['krill_greenweight_kg'].apply(my_log)
agg_data_finescale
# Out:
#                                          krill_greenweight_kg  record_count  \
# longitude_fsr latitude_fsr season_ccamlr
# -72.5         -64.75       1992                       41500.0             2
#               -64.25       1992                        8340.0             1
# -69.5         -65.25       1992                        4300.0             1
#                            1998                       29755.0             6
#               -64.75       1998                        1650.0             1
# ...                                                       ...           ...
#  148.5        -65.25       1990                        1960.0             2
#                            1994                         200.0             1
#               -64.75       1990                        1880.0             1
#  149.5        -64.75       1991                        3750.0             2
#  153.5        -64.25       1991                        2500.0             3
#
#                                           krill_greenweight_kg_log
# longitude_fsr latitude_fsr season_ccamlr
# -72.5         -64.75       1992                           4.618059
#               -64.25       1992                           3.921218
# -69.5         -65.25       1992                           3.633569
#                            1998                           4.473575
#               -64.75       1998                           3.217747
# ...                                                            ...
#  148.5        -65.25       1990                           3.292478
#                            1994                           2.303196
#               -64.75       1990                           3.274389
#  149.5        -64.75       1991                           3.574147
#  153.5        -64.25       1991                           3.398114
#
# [2504 rows x 3 columns]

# %%
# Some stats
agg_data_finescale.describe(include = "all")
# Out:
#         krill_greenweight_kg  record_count  krill_greenweight_kg_log
# count                 2504.0   2504.000000               2504.000000
# unique                2062.0           NaN                       NaN
# top                      0.0           NaN                       NaN
# freq                    20.0           NaN                       NaN
# mean                     NaN    172.193690                  4.614945
# std                      NaN    532.189439                  1.939498
# min                      NaN      0.000000                  0.000000
# 25%                      NaN      1.000000                  3.659254
# 50%                      NaN      6.000000                  4.867768
# 75%                      NaN     75.000000                  6.047007
# max                      NaN   7784.000000                  8.114487

# %%
plt.hist(agg_data_finescale['krill_greenweight_kg'])
plt.show()
plt.hist(agg_data_finescale['krill_greenweight_kg_log'])
# Out:
# (array([199.,  64.,  72., 138., 338., 442., 419., 428., 303., 101.]),
#  array([0.        , 0.81144874, 1.62289748, 2.43434622, 3.24579496,
#         4.0572437 , 4.86869245, 5.68014119, 6.49158993, 7.30303867,
#         8.11448741]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Formate to OCIM resolution
# Lastly we have to change the resolution of the data in order to have the same spatial grid as in OCIM and other datasets.
# To do this we round th coordinates of the "fine scale" data (1°x0.5°) to the  grid used for all other data : 2°x2° resolution with the coordinates of the center of the cells on odd numbers, using an atlantic center longitude format (from -180 to 180).

# %%
# make function to assign the right coordinates 
#(the center of the cell of the same spatial grid used for the othe data, i.e., a 2°x2° grid with cells centers on odd numbers)

def round_longitude_final(x):
    if x>=0 :
        if np.trunc(x)%2 == 0: # if its even
            return(x + 0.5)
        if np.trunc(x)%2 == 1: # if its odd
            return(x - 0.5)
        
    if x<0 :
        if np.trunc(x)%2 == 0: # if its even
            return(x - 0.5)
        if np.trunc(x)%2 == 1: # if its odd
            return(x + 0.5)


def round_latitude_final(y): # all values are negative
    if np.trunc(y)%2 == 0: # if its even
        return(np.trunc(y)-1)
    if np.trunc(y)%2 == 1: # if its odd
        return(np.trunc(y))

# %%
# Apply the rounding function to the coordinates long lat of the dataset
agg_data_year = agg_data_finescale.reset_index()
agg_data_year['longitude'] = agg_data_year['longitude_fsr'].apply(round_longitude_final)
agg_data_year['latitude'] = agg_data_year['latitude_fsr'].apply(round_latitude_final)
agg_data_year # 2504 rows × 8 columns
# Out:
#       longitude_fsr  latitude_fsr  season_ccamlr krill_greenweight_kg  \
# 0             -72.5        -64.75           1992              41500.0
# 1             -72.5        -64.25           1992               8340.0
# 2             -69.5        -65.25           1992               4300.0
# 3             -69.5        -65.25           1998              29755.0
# 4             -69.5        -64.75           1998               1650.0
# ...             ...           ...            ...                  ...
# 2499          148.5        -65.25           1990               1960.0
# 2500          148.5        -65.25           1994                200.0
# 2501          148.5        -64.75           1990               1880.0
# 2502          149.5        -64.75           1991               3750.0
# 2503          153.5        -64.25           1991               2500.0
#
#       record_count  krill_greenweight_kg_log  longitude  latitude
# 0                2                  4.618059      -73.0     -65.0
# 1                1                  3.921218      -73.0     -65.0
# 2                1                  3.633569      -69.0     -65.0
# 3                6                  4.473575      -69.0     -65.0
# 4                1                  3.217747      -69.0     -65.0
# ...            ...                       ...        ...       ...
# 2499             2                  3.292478      149.0     -65.0
# 2500             1                  2.303196      149.0     -65.0
# 2501             1                  3.274389      149.0     -65.0
# 2502             2                  3.574147      149.0     -65.0
# 2503             3                  3.398114      153.0     -65.0
#
# [2504 rows x 8 columns]

# %%
#select needed variables and set krill weight to numeric to perform summing
agg_data_year = agg_data_year[['longitude', 'latitude', 'season_ccamlr', 'krill_greenweight_kg', 'record_count']]
agg_data_year['krill_greenweight_kg'] = pd.to_numeric(agg_data_year['krill_greenweight_kg'])

# group by lat and long (cell coordinates), and ccamlr_season, sum the krill_biomass and  the record (=total count)
agg_data_year = agg_data_year.groupby(['longitude', 'latitude', 'season_ccamlr']).sum()

# log the krill weight
def my_log(x):
    return np.log10(x+1)

agg_data_year['krill_greenweight_kg_log'] = agg_data_year['krill_greenweight_kg'].apply(my_log)
agg_data_year # 1028 rows

# we can save this dataset for temporal analysis as e have the krill catch log for each year on the ocim spatial grid.
# Out:
# C:\Users\anael\AppData\Local\Temp\ipykernel_6844\2908458528.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   agg_data_year['krill_greenweight_kg'] = pd.to_numeric(agg_data_year['krill_greenweight_kg'])
#                                   krill_greenweight_kg  record_count  \
# longitude latitude season_ccamlr
# -73.0     -65.0    1992                        49840.0             3
# -69.0     -67.0    1989                         3250.0             1
#           -65.0    1989                         5950.0             3
#                    1992                         4300.0             1
#                    1998                        48875.0            11
# ...                                                ...           ...
#  147.0    -65.0    1990                        19190.0             8
#  149.0    -65.0    1990                         3840.0             3
#                    1991                         3750.0             2
#                    1994                          200.0             1
#  153.0    -65.0    1991                         2500.0             3
#
#                                   krill_greenweight_kg_log
# longitude latitude season_ccamlr
# -73.0     -65.0    1992                           4.697587
# -69.0     -67.0    1989                           3.512017
#           -65.0    1989                           3.774590
#                    1992                           3.633569
#                    1998                           4.689096
# ...                                                    ...
#  147.0    -65.0    1990                           4.283098
#  149.0    -65.0    1990                           3.584444
#                    1991                           3.574147
#                    1994                           2.303196
#  153.0    -65.0    1991                           3.398114
#
# [1028 rows x 3 columns]

# %%
# average the yearly raw krill catch 
data_agg_final = agg_data_year[['krill_greenweight_kg']].reset_index()
data_agg_final
# Out:
#       longitude  latitude  season_ccamlr  krill_greenweight_kg
# 0         -73.0     -65.0           1992               49840.0
# 1         -69.0     -67.0           1989                3250.0
# 2         -69.0     -65.0           1989                5950.0
# 3         -69.0     -65.0           1992                4300.0
# 4         -69.0     -65.0           1998               48875.0
# ...         ...       ...            ...                   ...
# 1023      147.0     -65.0           1990               19190.0
# 1024      149.0     -65.0           1990                3840.0
# 1025      149.0     -65.0           1991                3750.0
# 1026      149.0     -65.0           1994                 200.0
# 1027      153.0     -65.0           1991                2500.0
#
# [1028 rows x 4 columns]

# %% [markdown]
# ## Save this file
# File with the krill data aggrated in the grid cells. Save it to use it for further formating and exploration in the file "Krill_catch_data_formating_2"

# %%
# Save the dataframe as csv with all relevant data
os.chdir('C:/Users/anael/Documents/PhD/4_krill_fisheries_Carbon_seq_time/Git_repo/Key_Areas_krill_carbon_sequestration/outputs_formated_data/')
data_agg_final.to_csv('Krill_catch_aggregated.csv')
